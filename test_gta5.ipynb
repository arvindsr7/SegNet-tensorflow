# %%
from SegNet import SegNet
from drawings_object import display_color_legend

# %%
segnet = SegNet(conf_file='./config-GTA5.json')
# Out:
# VGG parameter loaded

# %%
#segnet.restore('./segnet_vgg_bayes_MFL_17000/gta5_five_class/model.ckpt-0/model.ckpt-0')

# %%
acc_final, acc_final_sidewalk, iu_final, iu_mean_final, prob_variance, logit_variance, pred_tot, var_tot = segnet.test_gta5()
# Out:
# INFO:tensorflow:Restoring parameters from ./segnet_vgg_bayes_MFL_17000/gta5_five_class/model.ckpt-0/model.ckpt-0
# 2369 CamVid test images are loaded
# Image Index 0: TEST Loss 0.007, TEST Accu  0.986
# accuracy = 0.985878
# mean IU  = 0.898411
#     class # 0 accuracy = 0.995711
#     class # 1 accuracy = 0.995077
#     class # 2 accuracy = 0.722983
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.945212
# Image Index 1: TEST Loss 0.007, TEST Accu  0.986
# accuracy = 0.986001
# mean IU  = 0.852651
#     class # 0 accuracy = 0.994640
#     class # 1 accuracy = 0.995715
#     class # 2 accuracy = 0.665998
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.810106
# Image Index 2: TEST Loss 0.005, TEST Accu  0.988
# accuracy = 0.987776
# mean IU  = 0.794204
#     class # 0 accuracy = 0.997723
#     class # 1 accuracy = 0.993221
#     class # 2 accuracy = 0.675294
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.560958
# Image Index 3: TEST Loss 0.005, TEST Accu  0.988
# accuracy = 0.988259
# mean IU  = 0.930228
#     class # 0 accuracy = 0.997252
#     class # 1 accuracy = 0.991847
#     class # 2 accuracy = 0.843523
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.939221
# Image Index 4: TEST Loss 0.005, TEST Accu  0.987
# accuracy = 0.987115
# mean IU  = 0.897213
#     class # 0 accuracy = 0.998268
#     class # 1 accuracy = 0.993429
#     class # 2 accuracy = 0.798959
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.847160
# Image Index 5: TEST Loss 0.004, TEST Accu  0.990
# accuracy = 0.990094
# mean IU  = 0.788292
#     class # 0 accuracy = 0.998344
#     class # 1 accuracy = 0.993489
#     class # 2 accuracy = 0.278810
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.924494
# Image Index 6: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.991114
# mean IU  = 0.837999
#     class # 0 accuracy = 0.998429
#     class # 1 accuracy = 0.991600
#     class # 2 accuracy = 0.489583
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.934870
# Image Index 7: TEST Loss 0.005, TEST Accu  0.992
# accuracy = 0.991898
# mean IU  = 0.871689
#     class # 0 accuracy = 0.996735
#     class # 1 accuracy = 0.992012
#     class # 2 accuracy = 0.622677
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.960388
# Image Index 8: TEST Loss 0.007, TEST Accu  0.989
# accuracy = 0.989073
# mean IU  = 0.892519
#     class # 0 accuracy = 0.994161
#     class # 1 accuracy = 0.988626
#     class # 2 accuracy = 0.731410
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.966770
# Image Index 9: TEST Loss 0.006, TEST Accu  0.991
# accuracy = 0.990888
# mean IU  = 0.921019
#     class # 0 accuracy = 0.996354
#     class # 1 accuracy = 0.988553
#     class # 2 accuracy = 0.784326
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.980678
# Image Index 10: TEST Loss 0.005, TEST Accu  0.990
# accuracy = 0.990069
# mean IU  = 0.941941
#     class # 0 accuracy = 0.996580
#     class # 1 accuracy = 0.993150
#     class # 2 accuracy = 0.871214
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.976612
# Image Index 11: TEST Loss 0.005, TEST Accu  0.989
# accuracy = 0.989127
# mean IU  = 0.968740
#     class # 0 accuracy = 0.997785
#     class # 1 accuracy = 0.976236
#     class # 2 accuracy = 0.972257
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985514
# Image Index 12: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992362
# mean IU  = 0.633909
#     class # 0 accuracy = 0.997763
#     class # 1 accuracy = 0.637906
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.992964
# Image Index 13: TEST Loss 0.003, TEST Accu  0.993
# accuracy = 0.992835
# mean IU  = 0.643686
#     class # 0 accuracy = 0.998876
#     class # 1 accuracy = 0.693057
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.992105
# Image Index 14: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992086
# mean IU  = 0.678749
#     class # 0 accuracy = 0.996550
#     class # 1 accuracy = 0.858959
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.991661
# Image Index 15: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992436
# mean IU  = 0.730371
#     class # 0 accuracy = 0.998134
#     class # 1 accuracy = 0.898748
#     class # 2 accuracy = 0.104895
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.991807
# Image Index 16: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991790
# mean IU  = 0.713704
#     class # 0 accuracy = 0.997397
#     class # 1 accuracy = 0.919141
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.992257
# Image Index 17: TEST Loss 0.004, TEST Accu  0.991
# accuracy = 0.991489
# mean IU  = 0.726713
#     class # 0 accuracy = 0.996769
#     class # 1 accuracy = 0.962872
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.991403
# Image Index 18: TEST Loss 0.005, TEST Accu  0.988
# accuracy = 0.988328
# mean IU  = 0.728537
#     class # 0 accuracy = 0.997040
#     class # 1 accuracy = 0.985045
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.975805
# Image Index 19: TEST Loss 0.004, TEST Accu  0.994
# accuracy = 0.993545
# mean IU  = 0.983601
#     class # 0 accuracy = 0.997379
#     class # 1 accuracy = 0.989166
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.989211
# Image Index 20: TEST Loss 0.003, TEST Accu  0.995
# accuracy = 0.994660
# mean IU  = 0.986951
#     class # 0 accuracy = 0.998630
#     class # 1 accuracy = 0.990385
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.990541
# Image Index 21: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.993190
# mean IU  = 0.979902
#     class # 0 accuracy = 0.997880
#     class # 1 accuracy = 0.975155
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.992910
# Image Index 22: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.991435
# mean IU  = 0.730699
#     class # 0 accuracy = 0.996768
#     class # 1 accuracy = 0.958620
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.994127
# Image Index 23: TEST Loss 0.005, TEST Accu  0.990
# accuracy = 0.989615
# mean IU  = 0.725515
#     class # 0 accuracy = 0.996438
#     class # 1 accuracy = 0.954491
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.987729
# Image Index 24: TEST Loss 0.006, TEST Accu  0.989
# accuracy = 0.989122
# mean IU  = 0.725764
#     class # 0 accuracy = 0.996092
#     class # 1 accuracy = 0.960370
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.986099
# Image Index 25: TEST Loss 0.005, TEST Accu  0.990
# accuracy = 0.990099
# mean IU  = 0.731035
#     class # 0 accuracy = 0.997042
#     class # 1 accuracy = 0.977497
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.980503
# Image Index 26: TEST Loss 0.005, TEST Accu  0.989
# accuracy = 0.988772
# mean IU  = 0.729021
#     class # 0 accuracy = 0.996548
#     class # 1 accuracy = 0.979109
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.973341
# Image Index 27: TEST Loss 0.006, TEST Accu  0.987
# accuracy = 0.987362
# mean IU  = 0.726047
#     class # 0 accuracy = 0.996061
#     class # 1 accuracy = 0.978530
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.967456
# Image Index 28: TEST Loss 0.007, TEST Accu  0.986
# accuracy = 0.986085
# mean IU  = 0.720542
#     class # 0 accuracy = 0.995438
#     class # 1 accuracy = 0.976482
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.957301
# Image Index 29: TEST Loss 0.007, TEST Accu  0.984
# accuracy = 0.984369
# mean IU  = 0.715979
#     class # 0 accuracy = 0.995911
#     class # 1 accuracy = 0.965545
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.953907
# Image Index 30: TEST Loss 0.009, TEST Accu  0.982
# accuracy = 0.982101
# mean IU  = 0.710292
#     class # 0 accuracy = 0.992580
#     class # 1 accuracy = 0.962879
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.953053
# Image Index 31: TEST Loss 0.009, TEST Accu  0.983
# accuracy = 0.983397
# mean IU  = 0.698991
#     class # 0 accuracy = 0.994109
#     class # 1 accuracy = 0.954904
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.924965
# Image Index 32: TEST Loss 0.010, TEST Accu  0.981
# accuracy = 0.981494
# mean IU  = 0.706817
#     class # 0 accuracy = 0.993478
#     class # 1 accuracy = 0.953807
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.952775
# Image Index 33: TEST Loss 0.010, TEST Accu  0.980
# accuracy = 0.979527
# mean IU  = 0.703812
#     class # 0 accuracy = 0.993490
#     class # 1 accuracy = 0.957474
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.932605
# Image Index 34: TEST Loss 0.010, TEST Accu  0.980
# accuracy = 0.979975
# mean IU  = 0.701041
#     class # 0 accuracy = 0.990219
#     class # 1 accuracy = 0.975177
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.918398
# Image Index 35: TEST Loss 0.011, TEST Accu  0.980
# accuracy = 0.979931
# mean IU  = 0.704612
#     class # 0 accuracy = 0.987909
#     class # 1 accuracy = 0.984199
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.922711
# Image Index 36: TEST Loss 0.011, TEST Accu  0.978
# accuracy = 0.978368
# mean IU  = 0.698886
#     class # 0 accuracy = 0.989712
#     class # 1 accuracy = 0.977457
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.912835
# Image Index 37: TEST Loss 0.012, TEST Accu  0.976
# accuracy = 0.976312
# mean IU  = 0.695434
#     class # 0 accuracy = 0.988885
#     class # 1 accuracy = 0.972597
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.918269
# Image Index 38: TEST Loss 0.012, TEST Accu  0.976
# accuracy = 0.976144
# mean IU  = 0.712009
#     class # 0 accuracy = 0.988045
#     class # 1 accuracy = 0.976440
#     class # 2 accuracy = 0.073684
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.904521
# Image Index 39: TEST Loss 0.013, TEST Accu  0.973
# accuracy = 0.972732
# mean IU  = 0.749974
#     class # 0 accuracy = 0.989523
#     class # 1 accuracy = 0.966754
#     class # 2 accuracy = 0.253414
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.887124
# Image Index 40: TEST Loss 0.012, TEST Accu  0.975
# accuracy = 0.974832
# mean IU  = 0.802059
#     class # 0 accuracy = 0.989044
#     class # 1 accuracy = 0.965238
#     class # 2 accuracy = 0.446392
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.907514
# Image Index 41: TEST Loss 0.011, TEST Accu  0.977
# accuracy = 0.976548
# mean IU  = 0.832401
#     class # 0 accuracy = 0.989801
#     class # 1 accuracy = 0.971749
#     class # 2 accuracy = 0.544067
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.925010
# Image Index 42: TEST Loss 0.012, TEST Accu  0.977
# accuracy = 0.976908
# mean IU  = 0.698820
#     class # 0 accuracy = 0.989327
#     class # 1 accuracy = 0.962147
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.932094
# Image Index 43: TEST Loss 0.012, TEST Accu  0.977
# accuracy = 0.976997
# mean IU  = 0.694108
#     class # 0 accuracy = 0.991355
#     class # 1 accuracy = 0.960455
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.910286
# Image Index 44: TEST Loss 0.013, TEST Accu  0.976
# accuracy = 0.975641
# mean IU  = 0.681171
#     class # 0 accuracy = 0.992017
#     class # 1 accuracy = 0.921842
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.906594
# Image Index 45: TEST Loss 0.012, TEST Accu  0.977
# accuracy = 0.977490
# mean IU  = 0.662732
#     class # 0 accuracy = 0.991872
#     class # 1 accuracy = 0.857681
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.923805
# Image Index 46: TEST Loss 0.012, TEST Accu  0.976
# accuracy = 0.976277
# mean IU  = 0.670807
#     class # 0 accuracy = 0.991417
#     class # 1 accuracy = 0.885897
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.917022
# Image Index 47: TEST Loss 0.012, TEST Accu  0.978
# accuracy = 0.978008
# mean IU  = 0.685161
#     class # 0 accuracy = 0.992710
#     class # 1 accuracy = 0.941176
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.893077
# Image Index 48: TEST Loss 0.012, TEST Accu  0.977
# accuracy = 0.977456
# mean IU  = 0.694555
#     class # 0 accuracy = 0.991965
#     class # 1 accuracy = 0.949201
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.918077
# Image Index 49: TEST Loss 0.012, TEST Accu  0.977
# accuracy = 0.976726
# mean IU  = 0.697478
#     class # 0 accuracy = 0.992463
#     class # 1 accuracy = 0.958309
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.912646
# Image Index 50: TEST Loss 0.012, TEST Accu  0.974
# accuracy = 0.973807
# mean IU  = 0.696496
#     class # 0 accuracy = 0.989451
#     class # 1 accuracy = 0.966362
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.908742
# Image Index 51: TEST Loss 0.011, TEST Accu  0.977
# accuracy = 0.977135
# mean IU  = 0.709681
#     class # 0 accuracy = 0.986121
#     class # 1 accuracy = 0.990417
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.930339
# Image Index 52: TEST Loss 0.015, TEST Accu  0.968
# accuracy = 0.967663
# mean IU  = 0.701416
#     class # 0 accuracy = 0.983249
#     class # 1 accuracy = 0.962498
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.954594
# Image Index 53: TEST Loss 0.016, TEST Accu  0.965
# accuracy = 0.964709
# mean IU  = 0.695905
#     class # 0 accuracy = 0.981973
#     class # 1 accuracy = 0.963113
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.948732
# Image Index 54: TEST Loss 0.014, TEST Accu  0.966
# accuracy = 0.966410
# mean IU  = 0.677224
#     class # 0 accuracy = 0.989669
#     class # 1 accuracy = 0.893882
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.955349
# Image Index 55: TEST Loss 0.014, TEST Accu  0.965
# accuracy = 0.965030
# mean IU  = 0.669819
#     class # 0 accuracy = 0.990984
#     class # 1 accuracy = 0.905707
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.948634
# Image Index 56: TEST Loss 0.015, TEST Accu  0.962
# accuracy = 0.962076
# mean IU  = 0.671982
#     class # 0 accuracy = 0.990483
#     class # 1 accuracy = 0.912215
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.941168
# Image Index 57: TEST Loss 0.013, TEST Accu  0.969
# accuracy = 0.969369
# mean IU  = 0.683125
#     class # 0 accuracy = 0.990523
#     class # 1 accuracy = 0.904756
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.954710
# Image Index 58: TEST Loss 0.012, TEST Accu  0.974
# accuracy = 0.974393
# mean IU  = 0.691523
#     class # 0 accuracy = 0.989451
#     class # 1 accuracy = 0.918169
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.965768
# Image Index 59: TEST Loss 0.011, TEST Accu  0.975
# accuracy = 0.975473
# mean IU  = 0.695741
#     class # 0 accuracy = 0.990940
#     class # 1 accuracy = 0.925607
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.968094
# Image Index 60: TEST Loss 0.011, TEST Accu  0.973
# accuracy = 0.973250
# mean IU  = 0.695675
#     class # 0 accuracy = 0.990588
#     class # 1 accuracy = 0.934813
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.963316
# Image Index 61: TEST Loss 0.012, TEST Accu  0.971
# accuracy = 0.970641
# mean IU  = 0.696583
#     class # 0 accuracy = 0.991842
#     class # 1 accuracy = 0.941999
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.955038
# Image Index 62: TEST Loss 0.013, TEST Accu  0.969
# accuracy = 0.969389
# mean IU  = 0.697809
#     class # 0 accuracy = 0.990793
#     class # 1 accuracy = 0.947482
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.951302
# Image Index 63: TEST Loss 0.012, TEST Accu  0.972
# accuracy = 0.971977
# mean IU  = 0.701906
#     class # 0 accuracy = 0.993428
#     class # 1 accuracy = 0.947611
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.953563
# Image Index 64: TEST Loss 0.012, TEST Accu  0.976
# accuracy = 0.976494
# mean IU  = 0.710513
#     class # 0 accuracy = 0.988924
#     class # 1 accuracy = 0.960981
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970892
# Image Index 65: TEST Loss 0.008, TEST Accu  0.982
# accuracy = 0.981578
# mean IU  = 0.720912
#     class # 0 accuracy = 0.994361
#     class # 1 accuracy = 0.975114
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.976518
# Image Index 66: TEST Loss 0.007, TEST Accu  0.984
# accuracy = 0.983945
# mean IU  = 0.726032
#     class # 0 accuracy = 0.992582
#     class # 1 accuracy = 0.985693
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.972599
# Image Index 67: TEST Loss 0.007, TEST Accu  0.985
# accuracy = 0.984896
# mean IU  = 0.726118
#     class # 0 accuracy = 0.995624
#     class # 1 accuracy = 0.984233
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.969623
# Image Index 68: TEST Loss 0.006, TEST Accu  0.987
# accuracy = 0.987106
# mean IU  = 0.729116
#     class # 0 accuracy = 0.996405
#     class # 1 accuracy = 0.981531
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.978110
# Image Index 69: TEST Loss 0.006, TEST Accu  0.987
# accuracy = 0.987470
# mean IU  = 0.729447
#     class # 0 accuracy = 0.994920
#     class # 1 accuracy = 0.977214
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.983054
# Image Index 70: TEST Loss 0.006, TEST Accu  0.986
# accuracy = 0.985774
# mean IU  = 0.721014
#     class # 0 accuracy = 0.995831
#     class # 1 accuracy = 0.966252
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.979744
# Image Index 71: TEST Loss 0.006, TEST Accu  0.986
# accuracy = 0.986386
# mean IU  = 0.738225
#     class # 0 accuracy = 0.995818
#     class # 1 accuracy = 0.976825
#     class # 2 accuracy = 0.042683
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.981834
# Image Index 72: TEST Loss 0.008, TEST Accu  0.982
# accuracy = 0.982475
# mean IU  = 0.724188
#     class # 0 accuracy = 0.992386
#     class # 1 accuracy = 0.982462
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970367
# Image Index 73: TEST Loss 0.007, TEST Accu  0.985
# accuracy = 0.984916
# mean IU  = 0.727817
#     class # 0 accuracy = 0.991199
#     class # 1 accuracy = 0.990789
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.972819
# Image Index 74: TEST Loss 0.007, TEST Accu  0.983
# accuracy = 0.982648
# mean IU  = 0.737180
#     class # 0 accuracy = 0.992756
#     class # 1 accuracy = 0.990985
#     class # 2 accuracy = 0.046610
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.964174
# Image Index 75: TEST Loss 0.008, TEST Accu  0.982
# accuracy = 0.982480
# mean IU  = 0.724766
#     class # 0 accuracy = 0.992846
#     class # 1 accuracy = 0.987501
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.965847
# Image Index 76: TEST Loss 0.008, TEST Accu  0.983
# accuracy = 0.983067
# mean IU  = 0.725443
#     class # 0 accuracy = 0.994245
#     class # 1 accuracy = 0.983130
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.969382
# Image Index 77: TEST Loss 0.007, TEST Accu  0.985
# accuracy = 0.985380
# mean IU  = 0.724234
#     class # 0 accuracy = 0.995466
#     class # 1 accuracy = 0.976431
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.977144
# Image Index 78: TEST Loss 0.008, TEST Accu  0.985
# accuracy = 0.984744
# mean IU  = 0.663576
#     class # 0 accuracy = 0.995923
#     class # 1 accuracy = 0.795908
#     class # 2 accuracy = 0.001481
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.975490
# Image Index 79: TEST Loss 0.007, TEST Accu  0.987
# accuracy = 0.986726
# mean IU  = 0.919507
#     class # 0 accuracy = 0.996262
#     class # 1 accuracy = 0.885714
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970175
# Image Index 80: TEST Loss 0.007, TEST Accu  0.985
# accuracy = 0.985084
# mean IU  = 0.722990
#     class # 0 accuracy = 0.994801
#     class # 1 accuracy = 0.980185
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.969912
# Image Index 81: TEST Loss 0.010, TEST Accu  0.978
# accuracy = 0.978462
# mean IU  = 0.711788
#     class # 0 accuracy = 0.991536
#     class # 1 accuracy = 0.962824
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.964035
# Image Index 82: TEST Loss 0.009, TEST Accu  0.981
# accuracy = 0.981356
# mean IU  = 0.700371
#     class # 0 accuracy = 0.987572
#     class # 1 accuracy = 0.917699
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.981469
# Image Index 83: TEST Loss 0.011, TEST Accu  0.977
# accuracy = 0.976889
# mean IU  = 0.663149
#     class # 0 accuracy = 0.989750
#     class # 1 accuracy = 0.825808
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.968405
# Image Index 84: TEST Loss 0.014, TEST Accu  0.967
# accuracy = 0.967436
# mean IU  = 0.660814
#     class # 0 accuracy = 0.990089
#     class # 1 accuracy = 0.848192
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.940737
# Image Index 85: TEST Loss 0.015, TEST Accu  0.970
# accuracy = 0.969773
# mean IU  = 0.668934
#     class # 0 accuracy = 0.993353
#     class # 1 accuracy = 0.877945
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.918921
# Image Index 86: TEST Loss 0.010, TEST Accu  0.980
# accuracy = 0.980478
# mean IU  = 0.687376
#     class # 0 accuracy = 0.994963
#     class # 1 accuracy = 0.880750
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.943248
# Image Index 87: TEST Loss 0.011, TEST Accu  0.975
# accuracy = 0.975187
# mean IU  = 0.684402
#     class # 0 accuracy = 0.995844
#     class # 1 accuracy = 0.881777
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.928775
# Image Index 88: TEST Loss 0.010, TEST Accu  0.981
# accuracy = 0.981248
# mean IU  = 0.704407
#     class # 0 accuracy = 0.991429
#     class # 1 accuracy = 0.910449
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.976560
# Image Index 89: TEST Loss 0.006, TEST Accu  0.988
# accuracy = 0.987776
# mean IU  = 0.724724
#     class # 0 accuracy = 0.998209
#     class # 1 accuracy = 0.951318
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.981775
# Image Index 90: TEST Loss 0.006, TEST Accu  0.988
# accuracy = 0.987525
# mean IU  = 0.716646
#     class # 0 accuracy = 0.997897
#     class # 1 accuracy = 0.962226
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.949510
# Image Index 91: TEST Loss 0.006, TEST Accu  0.990
# accuracy = 0.990059
# mean IU  = 0.710552
#     class # 0 accuracy = 0.997241
#     class # 1 accuracy = 0.978878
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.894757
# Image Index 92: TEST Loss 0.006, TEST Accu  0.988
# accuracy = 0.988279
# mean IU  = 0.692457
#     class # 0 accuracy = 0.996841
#     class # 1 accuracy = 0.973037
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.853997
# Image Index 93: TEST Loss 0.007, TEST Accu  0.988
# accuracy = 0.988082
# mean IU  = 0.658701
#     class # 0 accuracy = 0.994970
#     class # 1 accuracy = 0.984546
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.705545
# Image Index 94: TEST Loss 0.010, TEST Accu  0.982
# accuracy = 0.981953
# mean IU  = 0.623956
#     class # 0 accuracy = 0.994790
#     class # 1 accuracy = 0.970607
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.587620
# Image Index 95: TEST Loss 0.013, TEST Accu  0.977
# accuracy = 0.977451
# mean IU  = 0.664024
#     class # 0 accuracy = 0.992460
#     class # 1 accuracy = 0.969337
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.745487
# Image Index 96: TEST Loss 0.008, TEST Accu  0.985
# accuracy = 0.984615
# mean IU  = 0.685769
#     class # 0 accuracy = 0.993940
#     class # 1 accuracy = 0.986665
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.808992
# Image Index 97: TEST Loss 0.008, TEST Accu  0.986
# accuracy = 0.986287
# mean IU  = 0.655336
#     class # 0 accuracy = 0.994175
#     class # 1 accuracy = 0.990178
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.671847
# Image Index 98: TEST Loss 0.007, TEST Accu  0.988
# accuracy = 0.988023
# mean IU  = 0.652843
#     class # 0 accuracy = 0.995486
#     class # 1 accuracy = 0.994923
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.650955
# Image Index 99: TEST Loss 0.006, TEST Accu  0.988
# accuracy = 0.987628
# mean IU  = 0.666660
#     class # 0 accuracy = 0.997439
#     class # 1 accuracy = 0.990801
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.716593
# Image Index 100: TEST Loss 0.005, TEST Accu  0.988
# accuracy = 0.988033
# mean IU  = 0.694528
#     class # 0 accuracy = 0.998000
#     class # 1 accuracy = 0.989515
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.834511
# Image Index 101: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.990695
# mean IU  = 0.721950
#     class # 0 accuracy = 0.998207
#     class # 1 accuracy = 0.990958
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.926723
# Image Index 102: TEST Loss 0.007, TEST Accu  0.987
# accuracy = 0.987406
# mean IU  = 0.702994
#     class # 0 accuracy = 0.996161
#     class # 1 accuracy = 0.984765
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.890306
# Image Index 103: TEST Loss 0.007, TEST Accu  0.987
# accuracy = 0.986948
# mean IU  = 0.655018
#     class # 0 accuracy = 0.997281
#     class # 1 accuracy = 0.988382
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.683511
# Image Index 104: TEST Loss 0.007, TEST Accu  0.987
# accuracy = 0.987175
# mean IU  = 0.687130
#     class # 0 accuracy = 0.996980
#     class # 1 accuracy = 0.988866
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.810018
# Image Index 105: TEST Loss 0.007, TEST Accu  0.985
# accuracy = 0.985133
# mean IU  = 0.684273
#     class # 0 accuracy = 0.996901
#     class # 1 accuracy = 0.985731
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.808311
# Image Index 106: TEST Loss 0.006, TEST Accu  0.989
# accuracy = 0.988634
# mean IU  = 0.710376
#     class # 0 accuracy = 0.997102
#     class # 1 accuracy = 0.989513
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.894031
# Image Index 107: TEST Loss 0.006, TEST Accu  0.990
# accuracy = 0.989729
# mean IU  = 0.730049
#     class # 0 accuracy = 0.994685
#     class # 1 accuracy = 0.990704
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.968298
# Image Index 108: TEST Loss 0.006, TEST Accu  0.988
# accuracy = 0.987865
# mean IU  = 0.728350
#     class # 0 accuracy = 0.995196
#     class # 1 accuracy = 0.981850
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970423
# Image Index 109: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992071
# mean IU  = 0.733355
#     class # 0 accuracy = 0.997479
#     class # 1 accuracy = 0.990358
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970136
# Image Index 110: TEST Loss 0.005, TEST Accu  0.992
# accuracy = 0.992382
# mean IU  = 0.732474
#     class # 0 accuracy = 0.996267
#     class # 1 accuracy = 0.991713
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.973442
# Image Index 111: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.992919
# mean IU  = 0.734615
#     class # 0 accuracy = 0.997322
#     class # 1 accuracy = 0.992020
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970733
# Image Index 112: TEST Loss 0.006, TEST Accu  0.991
# accuracy = 0.990607
# mean IU  = 0.731679
#     class # 0 accuracy = 0.996075
#     class # 1 accuracy = 0.988342
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.969644
# Image Index 113: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.990873
# mean IU  = 0.730108
#     class # 0 accuracy = 0.997413
#     class # 1 accuracy = 0.989072
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.965416
# Image Index 114: TEST Loss 0.005, TEST Accu  0.992
# accuracy = 0.992165
# mean IU  = 0.733075
#     class # 0 accuracy = 0.997674
#     class # 1 accuracy = 0.988673
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.969829
# Image Index 115: TEST Loss 0.005, TEST Accu  0.992
# accuracy = 0.991647
# mean IU  = 0.731015
#     class # 0 accuracy = 0.997895
#     class # 1 accuracy = 0.987426
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.966034
# Image Index 116: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992234
# mean IU  = 0.733017
#     class # 0 accuracy = 0.996799
#     class # 1 accuracy = 0.988452
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.971771
# Image Index 117: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992352
# mean IU  = 0.733500
#     class # 0 accuracy = 0.995848
#     class # 1 accuracy = 0.990769
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970543
# Image Index 118: TEST Loss 0.007, TEST Accu  0.988
# accuracy = 0.988274
# mean IU  = 0.724507
#     class # 0 accuracy = 0.992416
#     class # 1 accuracy = 0.985420
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.964985
# Image Index 119: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.991282
# mean IU  = 0.728592
#     class # 0 accuracy = 0.996546
#     class # 1 accuracy = 0.985734
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.971713
# Image Index 120: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.990533
# mean IU  = 0.728968
#     class # 0 accuracy = 0.998324
#     class # 1 accuracy = 0.980738
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.974286
# Image Index 121: TEST Loss 0.003, TEST Accu  0.993
# accuracy = 0.993437
# mean IU  = 0.730458
#     class # 0 accuracy = 0.998456
#     class # 1 accuracy = 0.989488
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.964668
# Image Index 122: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991514
# mean IU  = 0.726296
#     class # 0 accuracy = 0.997230
#     class # 1 accuracy = 0.987539
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.946044
# Image Index 123: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.992791
# mean IU  = 0.729901
#     class # 0 accuracy = 0.998134
#     class # 1 accuracy = 0.986010
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.964077
# Image Index 124: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.993619
# mean IU  = 0.731149
#     class # 0 accuracy = 0.998431
#     class # 1 accuracy = 0.987974
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.967732
# Image Index 125: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992219
# mean IU  = 0.728690
#     class # 0 accuracy = 0.998852
#     class # 1 accuracy = 0.981913
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.964561
# Image Index 126: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.994127
# mean IU  = 0.734388
#     class # 0 accuracy = 0.998500
#     class # 1 accuracy = 0.988611
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.972484
# Image Index 127: TEST Loss 0.003, TEST Accu  0.996
# accuracy = 0.995542
# mean IU  = 0.737432
#     class # 0 accuracy = 0.998253
#     class # 1 accuracy = 0.992910
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.979370
# Image Index 128: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.994172
# mean IU  = 0.732227
#     class # 0 accuracy = 0.998436
#     class # 1 accuracy = 0.989303
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.967557
# Image Index 129: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.993821
# mean IU  = 0.733806
#     class # 0 accuracy = 0.998367
#     class # 1 accuracy = 0.987192
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.975978
# Image Index 130: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.993215
# mean IU  = 0.734727
#     class # 0 accuracy = 0.997901
#     class # 1 accuracy = 0.983890
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.982666
# Image Index 131: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991529
# mean IU  = 0.731564
#     class # 0 accuracy = 0.997244
#     class # 1 accuracy = 0.981986
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.979645
# Image Index 132: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.990789
# mean IU  = 0.730081
#     class # 0 accuracy = 0.996076
#     class # 1 accuracy = 0.982893
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.971589
# Image Index 133: TEST Loss 0.006, TEST Accu  0.990
# accuracy = 0.989778
# mean IU  = 0.723805
#     class # 0 accuracy = 0.995029
#     class # 1 accuracy = 0.983188
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.971450
# Image Index 134: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.993738
# mean IU  = 0.735073
#     class # 0 accuracy = 0.998219
#     class # 1 accuracy = 0.991032
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.973769
# Image Index 135: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.992821
# mean IU  = 0.726616
#     class # 0 accuracy = 0.998174
#     class # 1 accuracy = 0.993914
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.944814
# Image Index 136: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992313
# mean IU  = 0.726556
#     class # 0 accuracy = 0.997399
#     class # 1 accuracy = 0.994432
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.945988
# Image Index 137: TEST Loss 0.002, TEST Accu  0.996
# accuracy = 0.996484
# mean IU  = 0.741534
#     class # 0 accuracy = 0.997187
#     class # 1 accuracy = 0.997427
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.988151
# Image Index 138: TEST Loss 0.003, TEST Accu  0.996
# accuracy = 0.995592
# mean IU  = 0.739354
#     class # 0 accuracy = 0.996841
#     class # 1 accuracy = 0.997026
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.982079
# Image Index 139: TEST Loss 0.003, TEST Accu  0.996
# accuracy = 0.995814
# mean IU  = 0.739967
#     class # 0 accuracy = 0.997166
#     class # 1 accuracy = 0.995762
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.989216
# Image Index 140: TEST Loss 0.003, TEST Accu  0.995
# accuracy = 0.994788
# mean IU  = 0.737370
#     class # 0 accuracy = 0.997132
#     class # 1 accuracy = 0.995718
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.977206
# Image Index 141: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.994063
# mean IU  = 0.737376
#     class # 0 accuracy = 0.996286
#     class # 1 accuracy = 0.992138
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.987425
# Image Index 142: TEST Loss 0.004, TEST Accu  0.994
# accuracy = 0.994172
# mean IU  = 0.736851
#     class # 0 accuracy = 0.996409
#     class # 1 accuracy = 0.991614
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.989124
# Image Index 143: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.991386
# mean IU  = 0.733192
#     class # 0 accuracy = 0.994276
#     class # 1 accuracy = 0.987027
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985361
# Image Index 144: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.990759
# mean IU  = 0.728273
#     class # 0 accuracy = 0.997806
#     class # 1 accuracy = 0.981231
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.959225
# Image Index 145: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.993102
# mean IU  = 0.735699
#     class # 0 accuracy = 0.995805
#     class # 1 accuracy = 0.991084
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985599
# Image Index 146: TEST Loss 0.003, TEST Accu  0.995
# accuracy = 0.995128
# mean IU  = 0.741109
#     class # 0 accuracy = 0.996464
#     class # 1 accuracy = 0.994421
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.990901
# Image Index 147: TEST Loss 0.004, TEST Accu  0.994
# accuracy = 0.993876
# mean IU  = 0.739187
#     class # 0 accuracy = 0.994067
#     class # 1 accuracy = 0.993085
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.995269
# Image Index 148: TEST Loss 0.005, TEST Accu  0.993
# accuracy = 0.993442
# mean IU  = 0.738682
#     class # 0 accuracy = 0.994679
#     class # 1 accuracy = 0.993653
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.988553
# Image Index 149: TEST Loss 0.004, TEST Accu  0.994
# accuracy = 0.994497
# mean IU  = 0.740584
#     class # 0 accuracy = 0.995425
#     class # 1 accuracy = 0.994995
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.990287
# Image Index 150: TEST Loss 0.005, TEST Accu  0.993
# accuracy = 0.993481
# mean IU  = 0.738829
#     class # 0 accuracy = 0.992570
#     class # 1 accuracy = 0.995138
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.994670
# Image Index 151: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.992544
# mean IU  = 0.735193
#     class # 0 accuracy = 0.996034
#     class # 1 accuracy = 0.985090
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.988499
# Image Index 152: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.991479
# mean IU  = 0.733877
#     class # 0 accuracy = 0.995145
#     class # 1 accuracy = 0.984156
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985617
# Image Index 153: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.994063
# mean IU  = 0.736780
#     class # 0 accuracy = 0.998601
#     class # 1 accuracy = 0.987293
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.978262
# Image Index 154: TEST Loss 0.003, TEST Accu  0.995
# accuracy = 0.995069
# mean IU  = 0.736843
#     class # 0 accuracy = 0.998278
#     class # 1 accuracy = 0.989226
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.979623
# Image Index 155: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.992880
# mean IU  = 0.734279
#     class # 0 accuracy = 0.998040
#     class # 1 accuracy = 0.987971
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970085
# Image Index 156: TEST Loss 0.006, TEST Accu  0.989
# accuracy = 0.989078
# mean IU  = 0.757529
#     class # 0 accuracy = 0.997957
#     class # 1 accuracy = 0.983903
#     class # 2 accuracy = 0.120292
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.955595
# Image Index 157: TEST Loss 0.003, TEST Accu  0.994
# accuracy = 0.994122
# mean IU  = 0.734192
#     class # 0 accuracy = 0.998611
#     class # 1 accuracy = 0.985034
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.971871
# Image Index 158: TEST Loss 0.004, TEST Accu  0.993
# accuracy = 0.993397
# mean IU  = 0.724856
#     class # 0 accuracy = 0.997783
#     class # 1 accuracy = 0.987946
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.961773
# Image Index 159: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991543
# mean IU  = 0.726185
#     class # 0 accuracy = 0.998931
#     class # 1 accuracy = 0.976455
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.972147
# Image Index 160: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.990651
# mean IU  = 0.728618
#     class # 0 accuracy = 0.998675
#     class # 1 accuracy = 0.973432
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.976782
# Image Index 161: TEST Loss 0.004, TEST Accu  0.990
# accuracy = 0.990478
# mean IU  = 0.729913
#     class # 0 accuracy = 0.998124
#     class # 1 accuracy = 0.980021
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.975563
# Image Index 162: TEST Loss 0.004, TEST Accu  0.991
# accuracy = 0.990996
# mean IU  = 0.730316
#     class # 0 accuracy = 0.999131
#     class # 1 accuracy = 0.973735
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.979644
# Image Index 163: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991543
# mean IU  = 0.733993
#     class # 0 accuracy = 0.998247
#     class # 1 accuracy = 0.986596
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.977521
# Image Index 164: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991672
# mean IU  = 0.735015
#     class # 0 accuracy = 0.998416
#     class # 1 accuracy = 0.981982
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985205
# Image Index 165: TEST Loss 0.004, TEST Accu  0.994
# accuracy = 0.993659
# mean IU  = 0.737361
#     class # 0 accuracy = 0.997764
#     class # 1 accuracy = 0.989067
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985901
# Image Index 166: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991834
# mean IU  = 0.586850
#     class # 0 accuracy = 0.998086
#     class # 1 accuracy = 0.986421
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.976017
# Image Index 167: TEST Loss 0.006, TEST Accu  0.990
# accuracy = 0.989877
# mean IU  = 0.587064
#     class # 0 accuracy = 0.996547
#     class # 1 accuracy = 0.988577
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.978200
# Image Index 168: TEST Loss 0.006, TEST Accu  0.990
# accuracy = 0.989808
# mean IU  = 0.586675
#     class # 0 accuracy = 0.994337
#     class # 1 accuracy = 0.988702
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.980889
# Image Index 169: TEST Loss 0.005, TEST Accu  0.991
# accuracy = 0.991499
# mean IU  = 0.589343
#     class # 0 accuracy = 0.996279
#     class # 1 accuracy = 0.987749
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.989026
# Image Index 170: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.991598
# mean IU  = 0.589576
#     class # 0 accuracy = 0.996760
#     class # 1 accuracy = 0.985709
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.993049
# Image Index 171: TEST Loss 0.004, TEST Accu  0.991
# accuracy = 0.991272
# mean IU  = 0.736301
#     class # 0 accuracy = 0.996742
#     class # 1 accuracy = 0.985959
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.989792
# Image Index 172: TEST Loss 0.005, TEST Accu  0.992
# accuracy = 0.992096
# mean IU  = 0.597896
#     class # 0 accuracy = 0.995876
#     class # 1 accuracy = 0.994046
#     class # 2 accuracy = 0.040506
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.984287
# Image Index 173: TEST Loss 0.004, TEST Accu  0.992
# accuracy = 0.992071
# mean IU  = 0.630741
#     class # 0 accuracy = 0.996838
#     class # 1 accuracy = 0.991382
#     class # 2 accuracy = 0.219665
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.984835
# Image Index 174: TEST Loss 0.005, TEST Accu  0.990
# accuracy = 0.990158
# mean IU  = 0.666115
#     class # 0 accuracy = 0.997137
#     class # 1 accuracy = 0.983047
#     class # 2 accuracy = 0.435101
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.987052
# Image Index 175: TEST Loss 0.004, TEST Accu  0.990
# accuracy = 0.990128
# mean IU  = 0.654789
#     class # 0 accuracy = 0.998331
#     class # 1 accuracy = 0.984623
#     class # 2 accuracy = 0.359844
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.983609
# Image Index 176: TEST Loss 0.004, TEST Accu  0.991
# accuracy = 0.991070
# mean IU  = 0.868774
#     class # 0 accuracy = 0.997874
#     class # 1 accuracy = 0.985475
#     class # 2 accuracy = 0.570909
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.989559
# Image Index 177: TEST Loss 0.005, TEST Accu  0.989
# accuracy = 0.988792
# mean IU  = 0.878545
#     class # 0 accuracy = 0.995942
#     class # 1 accuracy = 0.989535
#     class # 2 accuracy = 0.611352
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.981152
# Image Index 178: TEST Loss 0.005, TEST Accu  0.987
# accuracy = 0.987175
# mean IU  = 0.942590
#     class # 0 accuracy = 0.997584
#     class # 1 accuracy = 0.983767
#     class # 2 accuracy = 0.855793
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.984402
# Image Index 179: TEST Loss 0.005, TEST Accu  0.989
# accuracy = 0.989181
# mean IU  = 0.869022
#     class # 0 accuracy = 0.996533
#     class # 1 accuracy = 0.986395
#     class # 2 accuracy = 0.599180
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.976362
# Image Index 180: TEST Loss 0.007, TEST Accu  0.985
# accuracy = 0.984551
# ...
# Image Index 2310: TEST Loss 0.012, TEST Accu  0.975
# accuracy = 0.975360
# mean IU  = 0.588528
#     class # 0 accuracy = 0.989840
#     class # 1 accuracy = 0.964855
#     class # 2 accuracy = 0.068452
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.978963
# Image Index 2311: TEST Loss 0.011, TEST Accu  0.975
# accuracy = 0.975182
# mean IU  = 0.614571
#     class # 0 accuracy = 0.987947
#     class # 1 accuracy = 0.944255
#     class # 2 accuracy = 0.227935
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.984763
# Image Index 2312: TEST Loss 0.011, TEST Accu  0.977
# accuracy = 0.977362
# mean IU  = 0.620272
#     class # 0 accuracy = 0.988271
#     class # 1 accuracy = 0.877981
#     class # 2 accuracy = 0.335301
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.992959
# Image Index 2313: TEST Loss 0.010, TEST Accu  0.977
# accuracy = 0.976667
# mean IU  = 0.621071
#     class # 0 accuracy = 0.990474
#     class # 1 accuracy = 0.785857
#     class # 2 accuracy = 0.426455
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.996226
# Image Index 2314: TEST Loss 0.012, TEST Accu  0.968
# accuracy = 0.967594
# mean IU  = 0.872396
#     class # 0 accuracy = 0.990068
#     class # 1 accuracy = 0.855225
#     class # 2 accuracy = 0.778590
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.984597
# Image Index 2315: TEST Loss 0.012, TEST Accu  0.971
# accuracy = 0.970962
# mean IU  = 0.822138
#     class # 0 accuracy = 0.988487
#     class # 1 accuracy = 0.881970
#     class # 2 accuracy = 0.527132
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.990395
# Image Index 2316: TEST Loss 0.013, TEST Accu  0.970
# accuracy = 0.969901
# mean IU  = 0.839493
#     class # 0 accuracy = 0.992283
#     class # 1 accuracy = 0.935574
#     class # 2 accuracy = 0.522480
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.985895
# Image Index 2317: TEST Loss 0.014, TEST Accu  0.971
# accuracy = 0.971144
# mean IU  = 0.627046
#     class # 0 accuracy = 0.991979
#     class # 1 accuracy = 0.961093
#     class # 2 accuracy = 0.624677
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2318: TEST Loss 0.013, TEST Accu  0.973
# accuracy = 0.973309
# mean IU  = 0.642331
#     class # 0 accuracy = 0.989986
#     class # 1 accuracy = 0.967451
#     class # 2 accuracy = 0.680630
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2319: TEST Loss 0.010, TEST Accu  0.979
# accuracy = 0.979384
# mean IU  = 0.633271
#     class # 0 accuracy = 0.994129
#     class # 1 accuracy = 0.977340
#     class # 2 accuracy = 0.499315
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.765432
# Image Index 2320: TEST Loss 0.013, TEST Accu  0.974
# accuracy = 0.974029
# mean IU  = 0.865246
#     class # 0 accuracy = 0.995103
#     class # 1 accuracy = 0.940707
#     class # 2 accuracy = 0.629759
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.971064
# Image Index 2321: TEST Loss 0.009, TEST Accu  0.980
# accuracy = 0.980089
# mean IU  = 0.715052
#     class # 0 accuracy = 0.995097
#     class # 1 accuracy = 0.963775
#     class # 2 accuracy = 0.720638
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.965955
# Image Index 2322: TEST Loss 0.012, TEST Accu  0.971
# accuracy = 0.970700
# mean IU  = 0.713731
#     class # 0 accuracy = 0.995168
#     class # 1 accuracy = 0.953242
#     class # 2 accuracy = 0.819997
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.895520
# Image Index 2323: TEST Loss 0.011, TEST Accu  0.972
# accuracy = 0.971652
# mean IU  = 0.720685
#     class # 0 accuracy = 0.995787
#     class # 1 accuracy = 0.954549
#     class # 2 accuracy = 0.852342
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.893985
# Image Index 2324: TEST Loss 0.010, TEST Accu  0.979
# accuracy = 0.979334
# mean IU  = 0.659095
#     class # 0 accuracy = 0.997133
#     class # 1 accuracy = 0.959958
#     class # 2 accuracy = 0.745825
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.652346
# Image Index 2325: TEST Loss 0.003, TEST Accu  0.989
# accuracy = 0.989236
# mean IU  = 0.900335
#     class # 0 accuracy = 0.999639
#     class # 1 accuracy = 0.903273
#     class # 2 accuracy = 0.849595
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2326: TEST Loss 0.002, TEST Accu  0.998
# accuracy = 0.997658
# mean IU  = 0.618853
#     class # 0 accuracy = 0.999694
#     class # 1 accuracy = 0.875273
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2327: TEST Loss 0.005, TEST Accu  0.986
# accuracy = 0.986134
# mean IU  = 0.866658
#     class # 0 accuracy = 0.999807
#     class # 1 accuracy = 0.822830
#     class # 2 accuracy = 0.836659
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2328: TEST Loss 0.009, TEST Accu  0.982
# accuracy = 0.982170
# mean IU  = 0.619522
#     class # 0 accuracy = 0.997504
#     class # 1 accuracy = 0.967491
#     class # 2 accuracy = 0.878335
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.293605
# Image Index 2329: TEST Loss 0.008, TEST Accu  0.985
# accuracy = 0.985419
# mean IU  = 0.534484
#     class # 0 accuracy = 0.996036
#     class # 1 accuracy = 0.960443
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.798528
# Image Index 2330: TEST Loss 0.011, TEST Accu  0.978
# accuracy = 0.978417
# mean IU  = 0.534819
#     class # 0 accuracy = 0.995995
#     class # 1 accuracy = 0.946152
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.894795
# Image Index 2331: TEST Loss 0.016, TEST Accu  0.971
# accuracy = 0.970902
# mean IU  = 0.628246
#     class # 0 accuracy = 0.993249
#     class # 1 accuracy = 0.942281
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2332: TEST Loss 0.010, TEST Accu  0.980
# accuracy = 0.980049
# mean IU  = 0.640183
#     class # 0 accuracy = 0.997118
#     class # 1 accuracy = 0.958685
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2333: TEST Loss 0.010, TEST Accu  0.978
# accuracy = 0.978422
# mean IU  = 0.553318
#     class # 0 accuracy = 0.997925
#     class # 1 accuracy = 0.951852
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.892727
# Image Index 2334: TEST Loss 0.009, TEST Accu  0.982
# accuracy = 0.982081
# mean IU  = 0.547773
#     class # 0 accuracy = 0.996023
#     class # 1 accuracy = 0.954446
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.862504
# Image Index 2335: TEST Loss 0.016, TEST Accu  0.968
# accuracy = 0.967702
# mean IU  = 0.508646
#     class # 0 accuracy = 0.995401
#     class # 1 accuracy = 0.941520
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.680908
# Image Index 2336: TEST Loss 0.036, TEST Accu  0.930
# accuracy = 0.930059
# mean IU  = 0.450540
#     class # 0 accuracy = 0.992186
#     class # 1 accuracy = 0.946198
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.457612
# Image Index 2337: TEST Loss 0.011, TEST Accu  0.977
# accuracy = 0.976691
# mean IU  = 0.568743
#     class # 0 accuracy = 0.996381
#     class # 1 accuracy = 0.942117
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.962397
# Image Index 2338: TEST Loss 0.007, TEST Accu  0.988
# accuracy = 0.987811
# mean IU  = 0.579185
#     class # 0 accuracy = 0.997239
#     class # 1 accuracy = 0.979502
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.953853
# Image Index 2339: TEST Loss 0.010, TEST Accu  0.983
# accuracy = 0.982909
# mean IU  = 0.574725
#     class # 0 accuracy = 0.996397
#     class # 1 accuracy = 0.962070
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.963424
# Image Index 2340: TEST Loss 0.010, TEST Accu  0.981
# accuracy = 0.980730
# mean IU  = 0.567766
#     class # 0 accuracy = 0.995952
#     class # 1 accuracy = 0.943698
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.969914
# Image Index 2341: TEST Loss 0.011, TEST Accu  0.974
# accuracy = 0.973669
# mean IU  = 0.564923
#     class # 0 accuracy = 0.994971
#     class # 1 accuracy = 0.952716
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.959470
# Image Index 2342: TEST Loss 0.013, TEST Accu  0.979
# accuracy = 0.979423
# mean IU  = 0.575145
#     class # 0 accuracy = 0.994343
#     class # 1 accuracy = 0.960926
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970851
# Image Index 2343: TEST Loss 0.015, TEST Accu  0.975
# accuracy = 0.975325
# mean IU  = 0.567980
#     class # 0 accuracy = 0.995844
#     class # 1 accuracy = 0.933869
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.965196
# Image Index 2344: TEST Loss 0.016, TEST Accu  0.973
# accuracy = 0.973042
# mean IU  = 0.566134
#     class # 0 accuracy = 0.995993
#     class # 1 accuracy = 0.935782
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.960585
# Image Index 2345: TEST Loss 0.020, TEST Accu  0.969
# accuracy = 0.968940
# mean IU  = 0.559112
#     class # 0 accuracy = 0.992899
#     class # 1 accuracy = 0.926474
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.947793
# Image Index 2346: TEST Loss 0.016, TEST Accu  0.974
# accuracy = 0.973851
# mean IU  = 0.565114
#     class # 0 accuracy = 0.993777
#     class # 1 accuracy = 0.945397
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.952061
# Image Index 2347: TEST Loss 0.015, TEST Accu  0.974
# accuracy = 0.973748
# mean IU  = 0.563142
#     class # 0 accuracy = 0.991316
#     class # 1 accuracy = 0.950760
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.949404
# Image Index 2348: TEST Loss 0.017, TEST Accu  0.970
# accuracy = 0.969645
# mean IU  = 0.694750
#     class # 0 accuracy = 0.993236
#     class # 1 accuracy = 0.930761
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.951839
# Image Index 2349: TEST Loss 0.018, TEST Accu  0.965
# accuracy = 0.965390
# mean IU  = 0.669479
#     class # 0 accuracy = 0.995589
#     class # 1 accuracy = 0.902903
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.866153
# Image Index 2350: TEST Loss 0.012, TEST Accu  0.974
# accuracy = 0.974482
# mean IU  = 0.550320
#     class # 0 accuracy = 0.996367
#     class # 1 accuracy = 0.940131
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.879454
# Image Index 2351: TEST Loss 0.013, TEST Accu  0.975
# accuracy = 0.975044
# mean IU  = 0.554096
#     class # 0 accuracy = 0.996924
#     class # 1 accuracy = 0.933626
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.895904
# Image Index 2352: TEST Loss 0.015, TEST Accu  0.971
# accuracy = 0.970873
# mean IU  = 0.562598
#     class # 0 accuracy = 0.985059
#     class # 1 accuracy = 0.950208
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.957274
# Image Index 2353: TEST Loss 0.016, TEST Accu  0.970
# accuracy = 0.969936
# mean IU  = 0.565023
#     class # 0 accuracy = 0.985868
#     class # 1 accuracy = 0.963224
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.949560
# Image Index 2354: TEST Loss 0.009, TEST Accu  0.981
# accuracy = 0.980641
# mean IU  = 0.576344
#     class # 0 accuracy = 0.993889
#     class # 1 accuracy = 0.980231
#     class # 2 accuracy = 0.023850
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.937162
# Image Index 2355: TEST Loss 0.012, TEST Accu  0.975
# accuracy = 0.974818
# mean IU  = 0.561200
#     class # 0 accuracy = 0.997617
#     class # 1 accuracy = 0.945757
#     class # 2 accuracy = 0.001214
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.924626
# Image Index 2356: TEST Loss 0.017, TEST Accu  0.961
# accuracy = 0.960676
# mean IU  = 0.547751
#     class # 0 accuracy = 0.995624
#     class # 1 accuracy = 0.938592
#     class # 2 accuracy = 0.080325
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.808108
# Image Index 2357: TEST Loss 0.012, TEST Accu  0.976
# accuracy = 0.975976
# mean IU  = 0.607527
#     class # 0 accuracy = 0.996451
#     class # 1 accuracy = 0.951726
#     class # 2 accuracy = 0.182891
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.970532
# Image Index 2358: TEST Loss 0.009, TEST Accu  0.980
# accuracy = 0.979956
# mean IU  = 0.612348
#     class # 0 accuracy = 0.996492
#     class # 1 accuracy = 0.964949
#     class # 2 accuracy = 0.167526
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.987412
# Image Index 2359: TEST Loss 0.008, TEST Accu  0.986
# accuracy = 0.985873
# mean IU  = 0.646806
#     class # 0 accuracy = 0.993202
#     class # 1 accuracy = 0.761417
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.991433
# Image Index 2360: TEST Loss 0.012, TEST Accu  0.969
# accuracy = 0.969221
# mean IU  = 0.664099
#     class # 0 accuracy = 0.994131
#     class # 1 accuracy = 0.532129
#     class # 2 accuracy = 0.252298
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.975376
# Image Index 2361: TEST Loss 0.014, TEST Accu  0.970
# accuracy = 0.970350
# mean IU  = 0.677470
#     class # 0 accuracy = 0.994628
#     class # 1 accuracy = 0.688085
#     class # 2 accuracy = 0.139555
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.982527
# Image Index 2362: TEST Loss 0.012, TEST Accu  0.974
# accuracy = 0.974073
# mean IU  = 0.788884
#     class # 0 accuracy = 0.993984
#     class # 1 accuracy = 0.855104
#     class # 2 accuracy = 0.383872
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.999190
# Image Index 2363: TEST Loss 0.014, TEST Accu  0.972
# accuracy = 0.972372
# mean IU  = 0.848733
#     class # 0 accuracy = 0.989379
#     class # 1 accuracy = 0.899471
#     class # 2 accuracy = 0.586797
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.999027
# Image Index 2364: TEST Loss 0.014, TEST Accu  0.963
# accuracy = 0.962579
# mean IU  = 0.842746
#     class # 0 accuracy = 0.996589
#     class # 1 accuracy = 0.918518
#     class # 2 accuracy = 0.542593
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.995751
# Image Index 2365: TEST Loss 0.015, TEST Accu  0.961
# accuracy = 0.960966
# mean IU  = 0.883269
#     class # 0 accuracy = 0.996365
#     class # 1 accuracy = 0.943406
#     class # 2 accuracy = 0.695027
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.983900
# Image Index 2366: TEST Loss 0.012, TEST Accu  0.976
# accuracy = 0.976036
# mean IU  = 0.691769
#     class # 0 accuracy = 0.996334
#     class # 1 accuracy = 0.943693
#     class # 2 accuracy = 0.874420
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2367: TEST Loss 0.018, TEST Accu  0.952
# accuracy = 0.951627
# mean IU  = 0.672903
#     class # 0 accuracy = 0.996700
#     class # 1 accuracy = 0.874156
#     class # 2 accuracy = 0.903768
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.000000
# Image Index 2368: TEST Loss 0.013, TEST Accu  0.973
# accuracy = 0.973383
# mean IU  = 0.635337
#     class # 0 accuracy = 0.994876
#     class # 1 accuracy = 0.922463
#     class # 2 accuracy = 0.391493
#     class # 3 accuracy = 0.000000
#     class # 4 accuracy = 0.966582
# Total Accuracy for test image:  0.9832464117800351
# Sidewalk Accuracy for test image:  0.9953214512894475
# Total MoI for test images:  [0.97675276 0.96191566 0.8439825  0.         0.95342635]
# mean MoI for test images:  0.7472154527190008

# %%
import numpy as np 

data = np.load('/home/ubuntu/segnet/SegNet-tensorflow/segnet_vgg_bayes_MFL_17000/model_17000/Data/valacc.npy')

# %%
print(data)
