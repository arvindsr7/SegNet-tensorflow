# %% [markdown]
# # Visual results (pixel-wise class predictions and model uncertainty)

# %% [markdown]
# ## Description

# %% [markdown]
# In this notebook, the main results of our best model are recreated. We show the prediction of the class labels and the model uncertainty for different images in the train, validation and test datasets, as well as for other images. In order to do so, we use the method *visual_results* from the *SegNet* class which is imported in the first code line of this notebook. The "visual_results" method can take three arguments:
# 1. ***dataset_type***: A string indicating the dataset type (either "TRAIN", "VAL" or "TEST"). By default it is "TEST".
# 2. ***images_index***: A list indicating the images indexes from the corresponding dataset. For instance, if we pass the list [0,20,47] we are requesting the prediction for the images that are found in the indexes 0, 20 and 47 of the dataset. This parameter can also be an integer value which corresponds to the number of different images that we want to display. In this case, we randomly pick the specified number of images from the corresponding dataset. By default it is set to 3.
# 3. ***FLAG_MAX_VOTE***: A boolean parameter indicating whether we want to use Max Voting (True) or Mean (False) at test time for the Bayesian model. By default it is set to False.
#
#
# For each of the displayed images we show (1) the original image, (2) the ground truth, i.e., the given pixel labels for training the network and obtain prediction accuracies, (3) the output of our model for the given image, and (4) the uncertainty of the model prediction (the darker the color is, the more uncertain the prediction in this pixel is).
#
# Finally, we also show the color legend for the different classes.

# %% [markdown]
# ## Usage

# %% [markdown]
# In order to run this notebook you need to have the files from https://github.com/toimcio/SegNet-tensorflow in the same directory than this notebook. Moreover, you need the 'vgg16.npy' file also in the running directory, which can be found in this link: https://mega.nz/#!YU1FWJrA!O1ywiCS2IiOlUCtCpI6HTJOMrneN-Qdv3ywQP5poecM. Finally, you need to download the saved model from https://drive.google.com/drive/folders/1tD-4FsN6s8c45R81bjqIG_f5VCS1j-Db and put the downloaded folder also in the running directory. Doing so the notebook should run without any problem. If there is any problem, make sure that the file and directory paths fit the ones from the 'config.json' file.

# %% [markdown]
# ## Imports

# %%
from SegNet import SegNet
from drawings_object import display_color_legend

# %%
# '''
# Automate training data output directory so as to avoid overwriting trained output.
# '''

# import time
# conf_file = 'config-GTA5.json'
# with open(conf_file) as f:
#     config = json.loads(f.read())
    
# time_now = time.ctime().lower()
# str_time = '-' + time_now[4:7] + time_now[8:10].replace(' ', '0') + '-' + time_now[11:13] + time_now[14:16]
# config["SAVE_MODEL_DIR"] = "./segnet_vgg_bayes_MFL_17000/model.ckpt-17000" + str_time

# json_object = json.dumps(config, indent=4)

# with open("config-GTA5.json", 'w') as f:
#     f.write(json_object)

# %% [markdown]
# ## Train dataset (367 images)

# %%
segnet = SegNet(conf_file='./config-GTA5_v2.json')
# Out:
# VGG parameter loaded
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/SegNet.py:59: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/SegNet.py:60: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/layers_object.py:41: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/layers_object.py:125: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/layers_object.py:48: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/ubuntu/miniconda3/envs/segnet/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:650: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/layers_object.py:13: to_double (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/layers_object.py:15: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/ubuntu/segnet/SegNet-tensorflow/SegNet.py:97: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.

# %%
batch_size = 5
n_images = 2369
epoch = 100
iterations = int((n_images / batch_size) * epoch)
segnet.train_gta5_v2(max_steps=iterations, batch_size=batch_size)
# Out:
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/inputs_object.py:93: slice_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(tuple(tensor_list)).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:373: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.range(limit).shuffle(limit).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:319: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/inputs_object.py:52: The name tf.read_file is deprecated. Please use tf.io.read_file instead.
#
# Filling queue with 300 input images before starting to train. This may take some time.
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/inputs_object.py:131: shuffle_batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.shuffle(min_after_dequeue).batch(batch_size)`.
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/inputs_object.py:140: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# generating image and label batch:
# Filling queue with 300 input images before starting to train. This may take some time.
# generating image and label batch:
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:80: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:110: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:112: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:262: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:262: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:266: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Running with Adam Optimizer with learning rate: 0.001
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/evaluation_object.py:276: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/SegNet.py:221: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/SegNet.py:224: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/SegNet.py:225: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/SegNet.py:228: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /tf/segnet/SegNet-tensorflow/SegNet.py:231: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Iteration 0/47380: Train Loss 0.794, Train Accu Total  0.077, Train Accu Sidewalk  0.062, Train Accu IOU  0.054
# accuracy = 0.092008
# mean IU  = 0.029062
#     class # 0 accuracy = 0.136036
#     class # 1 accuracy = 0.101076
#     class # 2 accuracy = 0.072497
#     class # 3 accuracy = 0.063911
#     class # 4 accuracy = 0.055822
#     class # 5 accuracy = 0.032417
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.274542
#     class # 8 accuracy = 0.091630
#     class # 9 accuracy = 0.047619
#     class # 10 accuracy = 0.038028
# per_class accuracy by logits in training time None
# start validating.......
# accuracy = 0.089130
# mean IU  = 0.030216
#     class # 0 accuracy = 0.140916
#     class # 1 accuracy = 0.098645
#     class # 2 accuracy = 0.070597
#     class # 3 accuracy = 0.065099
#     class # 4 accuracy = 0.054431
#     class # 5 accuracy = 0.026917
#     class # 6 accuracy = 0.123280
#     class # 7 accuracy = 0.260995
#     class # 8 accuracy = 0.099410
#     class # 9 accuracy = 0.099076
#     class # 10 accuracy = 0.038733
# Iteration 0/47380: Train Loss  0.794, Train Acc  0.077, Val Loss  0.755, Val Acc  0.089                              Val Acc Sidewalk 0.098  Val Acc IOU  0.081
# Iteration 1/47380: Train Loss 0.752, Train Accu Total  0.085, Train Accu Sidewalk  0.094, Train Accu IOU  0.077
# Iteration 2/47380: Train Loss 0.729, Train Accu Total  0.092, Train Accu Sidewalk  0.132, Train Accu IOU  0.094
# Iteration 3/47380: Train Loss 0.725, Train Accu Total  0.121, Train Accu Sidewalk  0.234, Train Accu IOU  0.172
# Iteration 4/47380: Train Loss 0.679, Train Accu Total  0.141, Train Accu Sidewalk  0.413, Train Accu IOU  0.195
# Iteration 5/47380: Train Loss 0.681, Train Accu Total  0.172, Train Accu Sidewalk  0.530, Train Accu IOU  0.248
# Iteration 6/47380: Train Loss 0.663, Train Accu Total  0.264, Train Accu Sidewalk  0.745, Train Accu IOU  0.399
# Iteration 7/47380: Train Loss 0.648, Train Accu Total  0.285, Train Accu Sidewalk  0.855, Train Accu IOU  0.396
# Iteration 8/47380: Train Loss 0.640, Train Accu Total  0.364, Train Accu Sidewalk  0.899, Train Accu IOU  0.500
# Iteration 9/47380: Train Loss 0.629, Train Accu Total  0.185, Train Accu Sidewalk  0.933, Train Accu IOU  0.182
# Iteration 10/47380: Train Loss 0.612, Train Accu Total  0.272, Train Accu Sidewalk  0.978, Train Accu IOU  0.311
# Iteration 11/47380: Train Loss 0.594, Train Accu Total  0.377, Train Accu Sidewalk  0.983, Train Accu IOU  0.526
# Iteration 12/47380: Train Loss 0.584, Train Accu Total  0.359, Train Accu Sidewalk  0.993, Train Accu IOU  0.476
# Iteration 13/47380: Train Loss 0.566, Train Accu Total  0.412, Train Accu Sidewalk  0.981, Train Accu IOU  0.539
# Iteration 14/47380: Train Loss 0.571, Train Accu Total  0.327, Train Accu Sidewalk  0.990, Train Accu IOU  0.418
# Iteration 15/47380: Train Loss 0.566, Train Accu Total  0.295, Train Accu Sidewalk  0.988, Train Accu IOU  0.354
# Iteration 16/47380: Train Loss 0.548, Train Accu Total  0.383, Train Accu Sidewalk  0.986, Train Accu IOU  0.514
# Iteration 17/47380: Train Loss 0.522, Train Accu Total  0.458, Train Accu Sidewalk  0.970, Train Accu IOU  0.694
# Iteration 18/47380: Train Loss 0.534, Train Accu Total  0.275, Train Accu Sidewalk  0.944, Train Accu IOU  0.313
# Iteration 19/47380: Train Loss 0.509, Train Accu Total  0.381, Train Accu Sidewalk  0.950, Train Accu IOU  0.549
# Iteration 20/47380: Train Loss 0.500, Train Accu Total  0.397, Train Accu Sidewalk  0.964, Train Accu IOU  0.551
# Iteration 21/47380: Train Loss 0.503, Train Accu Total  0.300, Train Accu Sidewalk  0.982, Train Accu IOU  0.425
# Iteration 22/47380: Train Loss 0.500, Train Accu Total  0.253, Train Accu Sidewalk  0.956, Train Accu IOU  0.306
# Iteration 23/47380: Train Loss 0.476, Train Accu Total  0.343, Train Accu Sidewalk  0.957, Train Accu IOU  0.428
# Iteration 24/47380: Train Loss 0.451, Train Accu Total  0.481, Train Accu Sidewalk  0.973, Train Accu IOU  0.748
# Iteration 25/47380: Train Loss 0.487, Train Accu Total  0.257, Train Accu Sidewalk  0.979, Train Accu IOU  0.276
# Iteration 26/47380: Train Loss 0.463, Train Accu Total  0.339, Train Accu Sidewalk  0.976, Train Accu IOU  0.408
# Iteration 27/47380: Train Loss 0.455, Train Accu Total  0.353, Train Accu Sidewalk  0.974, Train Accu IOU  0.376
# Iteration 28/47380: Train Loss 0.433, Train Accu Total  0.390, Train Accu Sidewalk  0.976, Train Accu IOU  0.591
# Iteration 29/47380: Train Loss 0.451, Train Accu Total  0.339, Train Accu Sidewalk  0.901, Train Accu IOU  0.432
# Iteration 30/47380: Train Loss 0.410, Train Accu Total  0.476, Train Accu Sidewalk  0.971, Train Accu IOU  0.703
# Iteration 31/47380: Train Loss 0.435, Train Accu Total  0.317, Train Accu Sidewalk  0.949, Train Accu IOU  0.338
# Iteration 32/47380: Train Loss 0.412, Train Accu Total  0.379, Train Accu Sidewalk  0.969, Train Accu IOU  0.424
# Iteration 33/47380: Train Loss 0.437, Train Accu Total  0.227, Train Accu Sidewalk  0.977, Train Accu IOU  0.173
# Iteration 34/47380: Train Loss 0.396, Train Accu Total  0.466, Train Accu Sidewalk  0.977, Train Accu IOU  0.571
# Iteration 35/47380: Train Loss 0.407, Train Accu Total  0.446, Train Accu Sidewalk  0.957, Train Accu IOU  0.484
# Iteration 36/47380: Train Loss 0.415, Train Accu Total  0.423, Train Accu Sidewalk  0.923, Train Accu IOU  0.499
# Iteration 37/47380: Train Loss 0.387, Train Accu Total  0.424, Train Accu Sidewalk  0.975, Train Accu IOU  0.556
# Iteration 38/47380: Train Loss 0.423, Train Accu Total  0.273, Train Accu Sidewalk  0.973, Train Accu IOU  0.215
# Iteration 39/47380: Train Loss 0.396, Train Accu Total  0.367, Train Accu Sidewalk  0.978, Train Accu IOU  0.388
# Iteration 40/47380: Train Loss 0.365, Train Accu Total  0.492, Train Accu Sidewalk  0.993, Train Accu IOU  0.587
# Iteration 41/47380: Train Loss 0.374, Train Accu Total  0.424, Train Accu Sidewalk  0.983, Train Accu IOU  0.522
# Iteration 42/47380: Train Loss 0.369, Train Accu Total  0.422, Train Accu Sidewalk  0.978, Train Accu IOU  0.454
# Iteration 43/47380: Train Loss 0.351, Train Accu Total  0.541, Train Accu Sidewalk  0.984, Train Accu IOU  0.631
# Iteration 44/47380: Train Loss 0.363, Train Accu Total  0.450, Train Accu Sidewalk  0.961, Train Accu IOU  0.454
# Iteration 45/47380: Train Loss 0.349, Train Accu Total  0.520, Train Accu Sidewalk  0.995, Train Accu IOU  0.667
# Iteration 46/47380: Train Loss 0.339, Train Accu Total  0.496, Train Accu Sidewalk  0.987, Train Accu IOU  0.589
# Iteration 47/47380: Train Loss 0.330, Train Accu Total  0.502, Train Accu Sidewalk  0.989, Train Accu IOU  0.674
# Iteration 48/47380: Train Loss 0.382, Train Accu Total  0.391, Train Accu Sidewalk  0.876, Train Accu IOU  0.449
# Iteration 49/47380: Train Loss 0.373, Train Accu Total  0.386, Train Accu Sidewalk  0.953, Train Accu IOU  0.440
# Iteration 50/47380: Train Loss 0.369, Train Accu Total  0.338, Train Accu Sidewalk  0.986, Train Accu IOU  0.326
# Iteration 51/47380: Train Loss 0.322, Train Accu Total  0.474, Train Accu Sidewalk  0.979, Train Accu IOU  0.615
# Iteration 52/47380: Train Loss 0.348, Train Accu Total  0.487, Train Accu Sidewalk  0.951, Train Accu IOU  0.523
# Iteration 53/47380: Train Loss 0.336, Train Accu Total  0.506, Train Accu Sidewalk  0.957, Train Accu IOU  0.539
# Iteration 54/47380: Train Loss 0.357, Train Accu Total  0.361, Train Accu Sidewalk  0.950, Train Accu IOU  0.379
# Iteration 55/47380: Train Loss 0.314, Train Accu Total  0.488, Train Accu Sidewalk  0.994, Train Accu IOU  0.573
# Iteration 56/47380: Train Loss 0.328, Train Accu Total  0.401, Train Accu Sidewalk  0.976, Train Accu IOU  0.467
# Iteration 57/47380: Train Loss 0.333, Train Accu Total  0.414, Train Accu Sidewalk  0.982, Train Accu IOU  0.399
# Iteration 58/47380: Train Loss 0.328, Train Accu Total  0.375, Train Accu Sidewalk  0.989, Train Accu IOU  0.424
# Iteration 59/47380: Train Loss 0.309, Train Accu Total  0.486, Train Accu Sidewalk  0.969, Train Accu IOU  0.576
# Iteration 60/47380: Train Loss 0.308, Train Accu Total  0.549, Train Accu Sidewalk  0.967, Train Accu IOU  0.663
# Iteration 61/47380: Train Loss 0.282, Train Accu Total  0.560, Train Accu Sidewalk  0.993, Train Accu IOU  0.675
# Iteration 62/47380: Train Loss 0.335, Train Accu Total  0.353, Train Accu Sidewalk  0.973, Train Accu IOU  0.312
# Iteration 63/47380: Train Loss 0.314, Train Accu Total  0.458, Train Accu Sidewalk  0.969, Train Accu IOU  0.445
# Iteration 64/47380: Train Loss 0.319, Train Accu Total  0.391, Train Accu Sidewalk  0.982, Train Accu IOU  0.392
# Iteration 65/47380: Train Loss 0.300, Train Accu Total  0.489, Train Accu Sidewalk  0.993, Train Accu IOU  0.551
# Iteration 66/47380: Train Loss 0.302, Train Accu Total  0.432, Train Accu Sidewalk  0.985, Train Accu IOU  0.389
# Iteration 67/47380: Train Loss 0.304, Train Accu Total  0.451, Train Accu Sidewalk  0.972, Train Accu IOU  0.528
# Iteration 68/47380: Train Loss 0.287, Train Accu Total  0.475, Train Accu Sidewalk  0.980, Train Accu IOU  0.494
# Iteration 69/47380: Train Loss 0.297, Train Accu Total  0.502, Train Accu Sidewalk  0.935, Train Accu IOU  0.563
# Iteration 70/47380: Train Loss 0.296, Train Accu Total  0.417, Train Accu Sidewalk  0.981, Train Accu IOU  0.450
# Iteration 71/47380: Train Loss 0.286, Train Accu Total  0.469, Train Accu Sidewalk  0.978, Train Accu IOU  0.471
# Iteration 96/47380: Train Loss 0.250, Train Accu Total  0.463, Train Accu Sidewalk  0.967, Train Accu IOU  0.523
# Iteration 97/47380: Train Loss 0.259, Train Accu Total  0.467, Train Accu Sidewalk  0.972, Train Accu IOU  0.459
# Iteration 98/47380: Train Loss 0.260, Train Accu Total  0.340, Train Accu Sidewalk  0.994, Train Accu IOU  0.450
# Iteration 99/47380: Train Loss 0.275, Train Accu Total  0.488, Train Accu Sidewalk  0.995, Train Accu IOU  0.438
# Iteration 100/47380: Train Loss 0.245, Train Accu Total  0.654, Train Accu Sidewalk  0.953, Train Accu IOU  0.795
# accuracy = 0.673001
# mean IU  = 0.123563
#     class # 0 accuracy = 0.080794
#     class # 1 accuracy = 0.988324
#     class # 2 accuracy = 0.000123
#     class # 3 accuracy = 0.002647
#     class # 4 accuracy = 0.909451
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000378
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000999
# per_class accuracy by logits in training time None
# Iteration 101/47380: Train Loss 0.266, Train Accu Total  0.410, Train Accu Sidewalk  0.994, Train Accu IOU  0.369
# Iteration 102/47380: Train Loss 0.247, Train Accu Total  0.466, Train Accu Sidewalk  0.990, Train Accu IOU  0.561
# Iteration 103/47380: Train Loss 0.242, Train Accu Total  0.502, Train Accu Sidewalk  0.984, Train Accu IOU  0.568
# Iteration 104/47380: Train Loss 0.241, Train Accu Total  0.579, Train Accu Sidewalk  0.983, Train Accu IOU  0.650
# Iteration 105/47380: Train Loss 0.258, Train Accu Total  0.484, Train Accu Sidewalk  0.991, Train Accu IOU  0.446
# Iteration 106/47380: Train Loss 0.262, Train Accu Total  0.442, Train Accu Sidewalk  0.957, Train Accu IOU  0.464
# Iteration 107/47380: Train Loss 0.245, Train Accu Total  0.523, Train Accu Sidewalk  0.983, Train Accu IOU  0.523
# Iteration 108/47380: Train Loss 0.245, Train Accu Total  0.455, Train Accu Sidewalk  0.988, Train Accu IOU  0.370
# Iteration 109/47380: Train Loss 0.272, Train Accu Total  0.345, Train Accu Sidewalk  0.974, Train Accu IOU  0.193
# Iteration 110/47380: Train Loss 0.252, Train Accu Total  0.463, Train Accu Sidewalk  0.996, Train Accu IOU  0.401
# Iteration 111/47380: Train Loss 0.233, Train Accu Total  0.507, Train Accu Sidewalk  0.983, Train Accu IOU  0.570
# Iteration 112/47380: Train Loss 0.230, Train Accu Total  0.477, Train Accu Sidewalk  0.988, Train Accu IOU  0.564
# Iteration 113/47380: Train Loss 0.216, Train Accu Total  0.558, Train Accu Sidewalk  0.995, Train Accu IOU  0.702
# Iteration 114/47380: Train Loss 0.251, Train Accu Total  0.354, Train Accu Sidewalk  0.998, Train Accu IOU  0.286
# Iteration 115/47380: Train Loss 0.211, Train Accu Total  0.557, Train Accu Sidewalk  0.994, Train Accu IOU  0.655
# Iteration 116/47380: Train Loss 0.241, Train Accu Total  0.458, Train Accu Sidewalk  0.991, Train Accu IOU  0.497
# Iteration 191/47380: Train Loss 0.238, Train Accu Total  0.335, Train Accu Sidewalk  0.997, Train Accu IOU  0.354
# Iteration 192/47380: Train Loss 0.225, Train Accu Total  0.388, Train Accu Sidewalk  0.968, Train Accu IOU  0.369
# Iteration 193/47380: Train Loss 0.215, Train Accu Total  0.414, Train Accu Sidewalk  0.998, Train Accu IOU  0.346
# Iteration 194/47380: Train Loss 0.191, Train Accu Total  0.505, Train Accu Sidewalk  0.993, Train Accu IOU  0.585
# Iteration 195/47380: Train Loss 0.195, Train Accu Total  0.561, Train Accu Sidewalk  0.990, Train Accu IOU  0.541
# Iteration 196/47380: Train Loss 0.206, Train Accu Total  0.465, Train Accu Sidewalk  0.977, Train Accu IOU  0.496
# Iteration 197/47380: Train Loss 0.226, Train Accu Total  0.307, Train Accu Sidewalk  0.984, Train Accu IOU  0.310
# Iteration 198/47380: Train Loss 0.193, Train Accu Total  0.488, Train Accu Sidewalk  0.994, Train Accu IOU  0.599
# Iteration 199/47380: Train Loss 0.207, Train Accu Total  0.495, Train Accu Sidewalk  0.993, Train Accu IOU  0.433
# Iteration 200/47380: Train Loss 0.228, Train Accu Total  0.411, Train Accu Sidewalk  0.982, Train Accu IOU  0.375
# accuracy = 0.410715
# mean IU  = 0.074668
#     class # 0 accuracy = 0.012987
#     class # 1 accuracy = 0.980095
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.003555
#     class # 4 accuracy = 0.904146
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000068
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000116
# per_class accuracy by logits in training time None
# Iteration 201/47380: Train Loss 0.213, Train Accu Total  0.367, Train Accu Sidewalk  0.976, Train Accu IOU  0.335
# Iteration 202/47380: Train Loss 0.202, Train Accu Total  0.491, Train Accu Sidewalk  0.999, Train Accu IOU  0.493
# Iteration 203/47380: Train Loss 0.183, Train Accu Total  0.524, Train Accu Sidewalk  0.996, Train Accu IOU  0.681
# Iteration 204/47380: Train Loss 0.193, Train Accu Total  0.609, Train Accu Sidewalk  0.998, Train Accu IOU  0.553
# Iteration 205/47380: Train Loss 0.200, Train Accu Total  0.540, Train Accu Sidewalk  0.987, Train Accu IOU  0.555
# Iteration 206/47380: Train Loss 0.186, Train Accu Total  0.568, Train Accu Sidewalk  0.988, Train Accu IOU  0.586
# Iteration 207/47380: Train Loss 0.214, Train Accu Total  0.481, Train Accu Sidewalk  0.985, Train Accu IOU  0.490
# Iteration 208/47380: Train Loss 0.212, Train Accu Total  0.449, Train Accu Sidewalk  0.985, Train Accu IOU  0.441
# Iteration 209/47380: Train Loss 0.183, Train Accu Total  0.585, Train Accu Sidewalk  0.996, Train Accu IOU  0.615
# Iteration 210/47380: Train Loss 0.217, Train Accu Total  0.301, Train Accu Sidewalk  0.976, Train Accu IOU  0.283
# Iteration 211/47380: Train Loss 0.196, Train Accu Total  0.529, Train Accu Sidewalk  0.987, Train Accu IOU  0.442
# Iteration 212/47380: Train Loss 0.228, Train Accu Total  0.465, Train Accu Sidewalk  0.943, Train Accu IOU  0.476
# Iteration 287/47380: Train Loss 0.182, Train Accu Total  0.457, Train Accu Sidewalk  0.988, Train Accu IOU  0.526
# Iteration 288/47380: Train Loss 0.181, Train Accu Total  0.574, Train Accu Sidewalk  0.992, Train Accu IOU  0.537
# Iteration 289/47380: Train Loss 0.192, Train Accu Total  0.436, Train Accu Sidewalk  0.998, Train Accu IOU  0.403
# Iteration 290/47380: Train Loss 0.199, Train Accu Total  0.396, Train Accu Sidewalk  0.992, Train Accu IOU  0.306
# Iteration 291/47380: Train Loss 0.187, Train Accu Total  0.415, Train Accu Sidewalk  0.988, Train Accu IOU  0.408
# Iteration 292/47380: Train Loss 0.202, Train Accu Total  0.443, Train Accu Sidewalk  0.990, Train Accu IOU  0.337
# Iteration 293/47380: Train Loss 0.202, Train Accu Total  0.388, Train Accu Sidewalk  0.999, Train Accu IOU  0.351
# Iteration 294/47380: Train Loss 0.175, Train Accu Total  0.499, Train Accu Sidewalk  0.997, Train Accu IOU  0.573
# Iteration 295/47380: Train Loss 0.235, Train Accu Total  0.197, Train Accu Sidewalk  0.996, Train Accu IOU  0.148
# Iteration 296/47380: Train Loss 0.197, Train Accu Total  0.463, Train Accu Sidewalk  0.989, Train Accu IOU  0.323
# Iteration 297/47380: Train Loss 0.188, Train Accu Total  0.536, Train Accu Sidewalk  0.992, Train Accu IOU  0.554
# Iteration 298/47380: Train Loss 0.194, Train Accu Total  0.439, Train Accu Sidewalk  1.000, Train Accu IOU  0.453
# Iteration 299/47380: Train Loss 0.179, Train Accu Total  0.453, Train Accu Sidewalk  1.000, Train Accu IOU  0.349
# Iteration 300/47380: Train Loss 0.168, Train Accu Total  0.528, Train Accu Sidewalk  0.995, Train Accu IOU  0.585
# accuracy = 0.539521
# mean IU  = 0.112410
#     class # 0 accuracy = 0.103424
#     class # 1 accuracy = 0.994778
#     class # 2 accuracy = 0.000170
#     class # 3 accuracy = 0.014083
#     class # 4 accuracy = 0.885073
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
# per_class accuracy by logits in training time None
# /tf/segnet/SegNet-tensorflow/evaluation_object.py:205: RuntimeWarning: invalid value encountered in true_divide
#   iu = np.diag(hist) / (hist.sum(1) + hist.sum(0) - np.diag(hist))
# Iteration 301/47380: Train Loss 0.164, Train Accu Total  0.554, Train Accu Sidewalk  1.000, Train Accu IOU  0.646
# Iteration 302/47380: Train Loss 0.180, Train Accu Total  0.526, Train Accu Sidewalk  0.981, Train Accu IOU  0.506
# Iteration 303/47380: Train Loss 0.182, Train Accu Total  0.517, Train Accu Sidewalk  0.996, Train Accu IOU  0.422
# Iteration 304/47380: Train Loss 0.178, Train Accu Total  0.489, Train Accu Sidewalk  0.992, Train Accu IOU  0.391
# Iteration 305/47380: Train Loss 0.191, Train Accu Total  0.358, Train Accu Sidewalk  0.984, Train Accu IOU  0.393
# Iteration 331/47380: Train Loss 0.175, Train Accu Total  0.497, Train Accu Sidewalk  0.990, Train Accu IOU  0.559
# Iteration 332/47380: Train Loss 0.173, Train Accu Total  0.537, Train Accu Sidewalk  0.989, Train Accu IOU  0.455
# Iteration 333/47380: Train Loss 0.191, Train Accu Total  0.561, Train Accu Sidewalk  0.982, Train Accu IOU  0.614
# Iteration 334/47380: Train Loss 0.178, Train Accu Total  0.545, Train Accu Sidewalk  0.991, Train Accu IOU  0.501
# Iteration 335/47380: Train Loss 0.193, Train Accu Total  0.504, Train Accu Sidewalk  0.971, Train Accu IOU  0.489
# Iteration 336/47380: Train Loss 0.163, Train Accu Total  0.597, Train Accu Sidewalk  0.984, Train Accu IOU  0.621
# Iteration 337/47380: Train Loss 0.189, Train Accu Total  0.536, Train Accu Sidewalk  0.987, Train Accu IOU  0.529
# Iteration 338/47380: Train Loss 0.167, Train Accu Total  0.562, Train Accu Sidewalk  0.998, Train Accu IOU  0.562
# Iteration 339/47380: Train Loss 0.176, Train Accu Total  0.625, Train Accu Sidewalk  0.994, Train Accu IOU  0.599
# Iteration 340/47380: Train Loss 0.166, Train Accu Total  0.627, Train Accu Sidewalk  0.988, Train Accu IOU  0.698
# Iteration 341/47380: Train Loss 0.223, Train Accu Total  0.387, Train Accu Sidewalk  0.995, Train Accu IOU  0.268
# Iteration 342/47380: Train Loss 0.182, Train Accu Total  0.533, Train Accu Sidewalk  0.992, Train Accu IOU  0.489
# Iteration 343/47380: Train Loss 0.175, Train Accu Total  0.602, Train Accu Sidewalk  0.983, Train Accu IOU  0.562
# Iteration 344/47380: Train Loss 0.196, Train Accu Total  0.503, Train Accu Sidewalk  0.998, Train Accu IOU  0.330
# ...
# Iteration 4018/47380: Train Loss 0.089, Train Accu Total  0.810, Train Accu Sidewalk  0.980, Train Accu IOU  0.730
# Iteration 4019/47380: Train Loss 0.072, Train Accu Total  0.837, Train Accu Sidewalk  0.975, Train Accu IOU  0.732
# Iteration 4020/47380: Train Loss 0.107, Train Accu Total  0.756, Train Accu Sidewalk  0.936, Train Accu IOU  0.637
# Iteration 4021/47380: Train Loss 0.074, Train Accu Total  0.821, Train Accu Sidewalk  0.949, Train Accu IOU  0.750
# Iteration 4022/47380: Train Loss 0.097, Train Accu Total  0.785, Train Accu Sidewalk  0.937, Train Accu IOU  0.823
# Iteration 4023/47380: Train Loss 0.094, Train Accu Total  0.750, Train Accu Sidewalk  0.960, Train Accu IOU  0.607
# Iteration 4024/47380: Train Loss 0.087, Train Accu Total  0.830, Train Accu Sidewalk  0.976, Train Accu IOU  0.894
# Iteration 4025/47380: Train Loss 0.049, Train Accu Total  0.900, Train Accu Sidewalk  0.988, Train Accu IOU  0.919
# Iteration 4026/47380: Train Loss 0.057, Train Accu Total  0.826, Train Accu Sidewalk  0.980, Train Accu IOU  0.819
# Iteration 4027/47380: Train Loss 0.159, Train Accu Total  0.723, Train Accu Sidewalk  0.959, Train Accu IOU  0.317
# Iteration 4077/47380: Train Loss 0.087, Train Accu Total  0.767, Train Accu Sidewalk  0.990, Train Accu IOU  0.741
# Iteration 4078/47380: Train Loss 0.096, Train Accu Total  0.780, Train Accu Sidewalk  0.985, Train Accu IOU  0.728
# Iteration 4079/47380: Train Loss 0.071, Train Accu Total  0.818, Train Accu Sidewalk  0.990, Train Accu IOU  0.755
# Iteration 4080/47380: Train Loss 0.061, Train Accu Total  0.847, Train Accu Sidewalk  0.998, Train Accu IOU  0.875
# Iteration 4081/47380: Train Loss 0.100, Train Accu Total  0.734, Train Accu Sidewalk  0.985, Train Accu IOU  0.638
# Iteration 4082/47380: Train Loss 0.088, Train Accu Total  0.743, Train Accu Sidewalk  0.985, Train Accu IOU  0.734
# Iteration 4083/47380: Train Loss 0.121, Train Accu Total  0.680, Train Accu Sidewalk  0.985, Train Accu IOU  0.451
# Iteration 4084/47380: Train Loss 0.075, Train Accu Total  0.846, Train Accu Sidewalk  0.976, Train Accu IOU  0.791
# Iteration 4085/47380: Train Loss 0.091, Train Accu Total  0.805, Train Accu Sidewalk  0.897, Train Accu IOU  0.783
# Iteration 4086/47380: Train Loss 0.083, Train Accu Total  0.830, Train Accu Sidewalk  0.947, Train Accu IOU  0.746
# Iteration 4087/47380: Train Loss 0.103, Train Accu Total  0.784, Train Accu Sidewalk  0.854, Train Accu IOU  0.698
# Iteration 4088/47380: Train Loss 0.093, Train Accu Total  0.748, Train Accu Sidewalk  0.978, Train Accu IOU  0.658
# Iteration 4089/47380: Train Loss 0.074, Train Accu Total  0.811, Train Accu Sidewalk  0.946, Train Accu IOU  0.755
# Iteration 4090/47380: Train Loss 0.086, Train Accu Total  0.816, Train Accu Sidewalk  0.967, Train Accu IOU  0.853
# Iteration 4091/47380: Train Loss 0.072, Train Accu Total  0.844, Train Accu Sidewalk  0.979, Train Accu IOU  0.790
# Iteration 4092/47380: Train Loss 0.081, Train Accu Total  0.801, Train Accu Sidewalk  0.982, Train Accu IOU  0.803
# Iteration 4093/47380: Train Loss 0.082, Train Accu Total  0.816, Train Accu Sidewalk  0.971, Train Accu IOU  0.751
# Iteration 4094/47380: Train Loss 0.083, Train Accu Total  0.821, Train Accu Sidewalk  0.977, Train Accu IOU  0.807
# Iteration 4095/47380: Train Loss 0.074, Train Accu Total  0.801, Train Accu Sidewalk  0.995, Train Accu IOU  0.661
# Iteration 4096/47380: Train Loss 0.066, Train Accu Total  0.867, Train Accu Sidewalk  0.986, Train Accu IOU  0.868
# Iteration 4097/47380: Train Loss 0.062, Train Accu Total  0.861, Train Accu Sidewalk  0.992, Train Accu IOU  0.843
# Iteration 4098/47380: Train Loss 0.090, Train Accu Total  0.757, Train Accu Sidewalk  0.986, Train Accu IOU  0.700
# Iteration 4099/47380: Train Loss 0.071, Train Accu Total  0.821, Train Accu Sidewalk  0.979, Train Accu IOU  0.746
# Iteration 4100/47380: Train Loss 0.071, Train Accu Total  0.793, Train Accu Sidewalk  0.988, Train Accu IOU  0.707
# accuracy = 0.800551
# mean IU  = 0.387477
#     class # 0 accuracy = 0.539756
#     class # 1 accuracy = 0.987933
#     class # 2 accuracy = 0.921348
#     class # 3 accuracy = 0.643073
#     class # 4 accuracy = 0.927421
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.565450
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.853404
# per_class accuracy by logits in training time None
# Iteration 4101/47380: Train Loss 0.095, Train Accu Total  0.777, Train Accu Sidewalk  0.954, Train Accu IOU  0.664
# Iteration 4102/47380: Train Loss 0.074, Train Accu Total  0.758, Train Accu Sidewalk  0.986, Train Accu IOU  0.817
# Iteration 4103/47380: Train Loss 0.069, Train Accu Total  0.844, Train Accu Sidewalk  0.994, Train Accu IOU  0.839
# Iteration 4104/47380: Train Loss 0.072, Train Accu Total  0.856, Train Accu Sidewalk  0.979, Train Accu IOU  0.744
# Iteration 4105/47380: Train Loss 0.069, Train Accu Total  0.845, Train Accu Sidewalk  0.950, Train Accu IOU  0.837
# Iteration 4106/47380: Train Loss 0.084, Train Accu Total  0.774, Train Accu Sidewalk  0.964, Train Accu IOU  0.627
# Iteration 4107/47380: Train Loss 0.070, Train Accu Total  0.829, Train Accu Sidewalk  0.978, Train Accu IOU  0.796
# Iteration 4108/47380: Train Loss 0.074, Train Accu Total  0.831, Train Accu Sidewalk  0.964, Train Accu IOU  0.795
# Iteration 4109/47380: Train Loss 0.069, Train Accu Total  0.825, Train Accu Sidewalk  0.958, Train Accu IOU  0.826
# Iteration 4110/47380: Train Loss 0.081, Train Accu Total  0.742, Train Accu Sidewalk  0.987, Train Accu IOU  0.760
# Iteration 4111/47380: Train Loss 0.092, Train Accu Total  0.761, Train Accu Sidewalk  0.954, Train Accu IOU  0.774
# Iteration 4112/47380: Train Loss 0.077, Train Accu Total  0.819, Train Accu Sidewalk  0.965, Train Accu IOU  0.739
# Iteration 4113/47380: Train Loss 0.193, Train Accu Total  0.616, Train Accu Sidewalk  0.899, Train Accu IOU  0.287
# Iteration 4114/47380: Train Loss 0.087, Train Accu Total  0.741, Train Accu Sidewalk  0.980, Train Accu IOU  0.640
# Iteration 4115/47380: Train Loss 0.063, Train Accu Total  0.861, Train Accu Sidewalk  0.969, Train Accu IOU  0.804
# Iteration 4116/47380: Train Loss 0.120, Train Accu Total  0.756, Train Accu Sidewalk  0.987, Train Accu IOU  0.724
# Iteration 4117/47380: Train Loss 0.101, Train Accu Total  0.786, Train Accu Sidewalk  0.962, Train Accu IOU  0.795
# Iteration 4118/47380: Train Loss 0.089, Train Accu Total  0.805, Train Accu Sidewalk  0.980, Train Accu IOU  0.675
# Iteration 4119/47380: Train Loss 0.087, Train Accu Total  0.799, Train Accu Sidewalk  0.991, Train Accu IOU  0.732
# Iteration 4120/47380: Train Loss 0.081, Train Accu Total  0.824, Train Accu Sidewalk  0.992, Train Accu IOU  0.793
# Iteration 4121/47380: Train Loss 0.082, Train Accu Total  0.834, Train Accu Sidewalk  0.952, Train Accu IOU  0.834
# Iteration 4122/47380: Train Loss 0.077, Train Accu Total  0.823, Train Accu Sidewalk  0.975, Train Accu IOU  0.775
# Iteration 4123/47380: Train Loss 0.071, Train Accu Total  0.843, Train Accu Sidewalk  0.982, Train Accu IOU  0.844
# Iteration 4124/47380: Train Loss 0.093, Train Accu Total  0.801, Train Accu Sidewalk  0.978, Train Accu IOU  0.760
# Iteration 4125/47380: Train Loss 0.075, Train Accu Total  0.811, Train Accu Sidewalk  0.979, Train Accu IOU  0.746
# Iteration 4126/47380: Train Loss 0.106, Train Accu Total  0.730, Train Accu Sidewalk  0.964, Train Accu IOU  0.698
# Iteration 4127/47380: Train Loss 0.069, Train Accu Total  0.823, Train Accu Sidewalk  0.992, Train Accu IOU  0.792
# Iteration 4128/47380: Train Loss 0.085, Train Accu Total  0.803, Train Accu Sidewalk  0.951, Train Accu IOU  0.791
# Iteration 4129/47380: Train Loss 0.083, Train Accu Total  0.783, Train Accu Sidewalk  0.986, Train Accu IOU  0.510
# Iteration 4130/47380: Train Loss 0.069, Train Accu Total  0.819, Train Accu Sidewalk  0.952, Train Accu IOU  0.790
# Iteration 4131/47380: Train Loss 0.076, Train Accu Total  0.759, Train Accu Sidewalk  0.986, Train Accu IOU  0.846
# Iteration 4132/47380: Train Loss 0.085, Train Accu Total  0.749, Train Accu Sidewalk  0.959, Train Accu IOU  0.748
# Iteration 4133/47380: Train Loss 0.086, Train Accu Total  0.776, Train Accu Sidewalk  0.984, Train Accu IOU  0.784
# Iteration 4134/47380: Train Loss 0.068, Train Accu Total  0.850, Train Accu Sidewalk  0.979, Train Accu IOU  0.786
# Iteration 4135/47380: Train Loss 0.090, Train Accu Total  0.808, Train Accu Sidewalk  0.911, Train Accu IOU  0.744
# Iteration 4136/47380: Train Loss 0.103, Train Accu Total  0.716, Train Accu Sidewalk  0.978, Train Accu IOU  0.793
# Iteration 4137/47380: Train Loss 0.137, Train Accu Total  0.633, Train Accu Sidewalk  0.967, Train Accu IOU  0.500
# Iteration 4138/47380: Train Loss 0.063, Train Accu Total  0.839, Train Accu Sidewalk  0.989, Train Accu IOU  0.890
# Iteration 4139/47380: Train Loss 0.066, Train Accu Total  0.865, Train Accu Sidewalk  0.976, Train Accu IOU  0.844
# Iteration 4140/47380: Train Loss 0.091, Train Accu Total  0.781, Train Accu Sidewalk  0.983, Train Accu IOU  0.751
# Iteration 4141/47380: Train Loss 0.062, Train Accu Total  0.850, Train Accu Sidewalk  0.991, Train Accu IOU  0.806
# Iteration 4142/47380: Train Loss 0.085, Train Accu Total  0.762, Train Accu Sidewalk  0.966, Train Accu IOU  0.699
# Iteration 4143/47380: Train Loss 0.073, Train Accu Total  0.817, Train Accu Sidewalk  0.977, Train Accu IOU  0.879
# Iteration 4144/47380: Train Loss 0.084, Train Accu Total  0.765, Train Accu Sidewalk  0.995, Train Accu IOU  0.734
# Iteration 4145/47380: Train Loss 0.060, Train Accu Total  0.848, Train Accu Sidewalk  0.983, Train Accu IOU  0.862
# Iteration 4146/47380: Train Loss 0.086, Train Accu Total  0.745, Train Accu Sidewalk  0.991, Train Accu IOU  0.632
# Iteration 4147/47380: Train Loss 0.079, Train Accu Total  0.830, Train Accu Sidewalk  0.988, Train Accu IOU  0.877
# Iteration 4148/47380: Train Loss 0.108, Train Accu Total  0.732, Train Accu Sidewalk  0.954, Train Accu IOU  0.572
# Iteration 4149/47380: Train Loss 0.088, Train Accu Total  0.854, Train Accu Sidewalk  0.930, Train Accu IOU  0.882
# Iteration 4150/47380: Train Loss 0.094, Train Accu Total  0.725, Train Accu Sidewalk  0.966, Train Accu IOU  0.655
# Iteration 4151/47380: Train Loss 0.057, Train Accu Total  0.885, Train Accu Sidewalk  0.994, Train Accu IOU  0.895

# %%
segnet.save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-cca1e019a649> in <module>
# ----> 1 segnet.save()
#
# ~/segnet/SegNet-tensorflow/SegNet.py in save(self)
#    1285
#    1286     def save(self):
# -> 1287         np.save(os.path.join(self.saved_dir, "Data", "trainloss"), self.train_loss)
#    1288         np.save(os.path.join(self.saved_dir, "Data", "trainacc"), self.train_accuracy)
#    1289         np.save(os.path.join(self.saved_dir, "Data", "valloss"), self.val_loss)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~/miniconda3/envs/segnet/lib/python3.7/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     539         if not file.endswith('.npy'):
#     540             file = file + '.npy'
# --> 541         fid = open(file, "wb")
#     542         own_fid = True
#     543
#
# FileNotFoundError: [Errno 2] No such file or directory: './segnet_vgg_bayes_MFL_17000/gta5_v2/model.ckpt-0/Data/trainloss.npy'

# %%
#segnet.restore('./segnet_vgg_bayes_MFL_17000/gta5_model/model.ckpt-0')
#segnet.print_checkpoint(all_tensors=False, tensor_name='conv1_1/biases')

# %%
SegNet(conf_file='./config-GTA5_v2.json').visual_results_gta5(dataset_type = "VAL", images_index = 10, FLAG_MAX_VOTE = False)
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./segnet_vgg_bayes_MFL_17000/gta5_five_class/model.ckpt-0/model.ckpt-0
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# NotFoundError: 2 root error(s) found.
#   (0) Not found: Key conv1_1/biases not found in checkpoint
# 	 [[{{node save/RestoreV2}}]]
# 	 [[save/RestoreV2/_133]]
#   (1) Not found: Key conv1_1/biases not found in checkpoint
# 	 [[{{node save/RestoreV2}}]]
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py in restore(self, sess, save_path)
#    1289         sess.run(self.saver_def.restore_op_name,
# -> 1290                  {self.saver_def.filename_tensor_name: save_path})
#    1291     except errors.NotFoundError as err:
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#
# NotFoundError: 2 root error(s) found.
#   (0) Not found: Key conv1_1/biases not found in checkpoint
# 	 [[node save/RestoreV2 (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# 	 [[save/RestoreV2/_133]]
#   (1) Not found: Key conv1_1/biases not found in checkpoint
# 	 [[node save/RestoreV2 (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'save/RestoreV2':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3051, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3242, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-51d31bbcab8e>", line 1, in <module>
#     SegNet(conf_file='./config-GTA5.json').visual_results_gta5(dataset_type = "VAL", images_index = 10, FLAG_MAX_VOTE = False)
#   File "/tf/segnet/SegNet-tensorflow/SegNet.py", line 609, in visual_results_gta5
#     saver = tf.train.Saver(name_to_var_map)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 828, in __init__
#     self.build()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py in restore(self, sess, save_path)
#    1299       try:
# -> 1300         names_to_keys = object_graph_key_mapping(save_path)
#    1301       except errors.NotFoundError:
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py in object_graph_key_mapping(checkpoint_path)
#    1617   reader = pywrap_tensorflow.NewCheckpointReader(checkpoint_path)
# -> 1618   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1619   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in get_tensor(self, tensor_str)
#     914
# --> 915       return CheckpointReader_GetTensor(self, compat.as_bytes(tensor_str))
#     916
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-10-51d31bbcab8e> in <module>
# ----> 1 SegNet(conf_file='./config-GTA5.json').visual_results_gta5(dataset_type = "VAL", images_index = 10, FLAG_MAX_VOTE = False)
#
# ~tf/segnet/SegNet-tensorflow/SegNet.py in visual_results_gta5(self, dataset_type, images_index, FLAG_MAX_VOTE)
#     608             # Restore saved session
#     609             saver = tf.train.Saver(name_to_var_map)
# --> 610             saver.restore(sess, train_dir)
#     611
#     612             _, _, prediction = cal_loss_gta5(self.logits, self.labels_pl, 2)
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py in restore(self, sess, save_path)
#    1304         # a helpful message (b/110263146)
#    1305         raise _wrap_restore_error_with_msg(
# -> 1306             err, "a Variable name or other graph key that is missing")
#    1307
#    1308       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# 2 root error(s) found.
#   (0) Not found: Key conv1_1/biases not found in checkpoint
# 	 [[node save/RestoreV2 (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# 	 [[save/RestoreV2/_133]]
#   (1) Not found: Key conv1_1/biases not found in checkpoint
# 	 [[node save/RestoreV2 (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'save/RestoreV2':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3051, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3242, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-51d31bbcab8e>", line 1, in <module>
#     SegNet(conf_file='./config-GTA5.json').visual_results_gta5(dataset_type = "VAL", images_index = 10, FLAG_MAX_VOTE = False)
#   File "/tf/segnet/SegNet-tensorflow/SegNet.py", line 609, in visual_results_gta5
#     saver = tf.train.Saver(name_to_var_map)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 828, in __init__
#     self.build()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
#SegNet(conf_file='./config-GTA5.json').visual_results_gta5(dataset_type = "TRAIN", images_index = 10, FLAG_MAX_VOTE = False)
